# %% [markdown]
# # About notebook

# %% [markdown]
# Dataset
# *	Groningen Meaning Bank (version 2.2.0)
# *	Task: named entity recognition
# *	Target – named entity tags (BIO + entity type)
# *	Input data:
#   * Use “en.met” files to extract the subcorpus
#   corpus = 'Voice of America' (for honogeneity of the input data set)
#   * Use "en.tags" files for the main input data:
#       *	raw tokens + may use the lemmas and the POS-tags
#   (i.e. take the “golden” POS-tagging);
#       *	which means:
#         *	first three columns for input: ['word', 'pos', 'lemma']
#         *	the fourth column for target variable (‘ne_tags’)
#         (BIO annotation + the named-entity type in one tag)

# %% [markdown]
# # Tasks

# %% [markdown]
# 1.	The most trivial model = supervised HMM:
#   *	Take hmmlearn (former sklearn), modify MultinomialHMM (I.e. inherit a new class from _BaseHMM making it a modified copy of the latter) to allow for supervised HMM training. The states of the HMM model = the NE tags.
#   *	NOTE: may use NaiveBayes to learn emission probabilities in a supervized manner.
#   *	Or implement from scratch (with Viterbi for prediction).
#   *	NOTE: use tuples of features for X (not just the word, but additional info).
#   *	NOTE: use smoothing for state transitions.
# 2.	CRF
#   *	Modify the input features;
#   *	Use CRFSuite.
# 3.	Bi-LSTM:
#   *	Use keras or tensorflow;
#   *	https://github.com/hse-aml/natural-language-processing/blob/master/week2/week2-NER.ipynb
#   *	A plus for incorporating CNN-layers;

# %% [markdown]
# # Metrics

# %% [markdown]
# * normalized confusion matrices, precision, recall, F-score
# (macro- and micro-)
# * (token level, entity level, partial matching (i.e. boundary-detection problem), binary).
# NOTE: taking into account vocabulary transfer is a plus.

# %% [markdown]
# # Evaluation Criteria

# %% [markdown]
# Scoring (14.5 max):
# *	Dataset overview – 0.5
#   *	text lengths, vocabulary size, frequencies of patterns (<UNK-type-i>)
#   *	stats over the target tags
# *	Feature engineering – 2 (1+1)
#   *	grammatical words = closed set (~ stop words)
#   *	Stemming + POS
#   *	Word shape
#   *	Ad hoc features ( +1)
# *	Word patterns -> encode types of unknown words +0.5
# *	Smoothing in HMM – 0.5
#   *	In HMM: for state transitions.
# *	Incorporating tupled features in HMM (on top of tokens) – 1
# *	The correct HMM implementation – 1
# *	More fine-grained feature engineering for the Neural Network + 0.5
#   *	Differentiate between POS-relevancy for the word and the context, etc.
#   *	Sentence-level features (may use “golden” sentence-splitting)
# *	Evaluation (on all levels) – 1
# *	Conclusion on HMM deficiency (as a model) – 1
# *	CRF: 1 point for use and evaluation, + 0.5 points for comparison and conclusions;
# *	NN:
#   *	Main network: 4
#   *	CNN layers: +2
#
# Libraries: hmmlearn, crfsuite, tensorflow, keras

# %% [markdown]
# # Libs import

# %%
# %autosave 180
# %load_ext autoreload
# %autoreload 2

from nltk import word_tokenize, pos_tag, ne_chunk
import os
import pandas as pd
import codecs
from collections import Counter
import re
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_validate, ShuffleSplit
from sklearn_crfsuite import CRF
from sklearn.metrics import recall_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

# %matplotlib inline
# Out:
# Autosaving every 180 seconds
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Configs

# %%
data_path = 'D:\Data\gmb-2.2.0\data'
print('data found:', os.listdir(data_path))
# Out:
# data found: ['p00', 'p01', 'p02', 'p03', 'p04', 'p05', 'p06', 'p07', 'p08', 'p09', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23', 'p24', 'p25', 'p26', 'p27', 'p28', 'p29', 'p30', 'p31', 'p32', 'p33', 'p34', 'p35', 'p36', 'p37', 'p38', 'p39', 'p40', 'p41', 'p42', 'p43', 'p44', 'p45', 'p46', 'p47', 'p48', 'p49', 'p50', 'p51', 'p52', 'p53', 'p54', 'p55', 'p56', 'p57', 'p58', 'p59', 'p60', 'p61', 'p62', 'p63', 'p64', 'p65', 'p66', 'p67', 'p68', 'p69', 'p70', 'p71', 'p72', 'p73', 'p74', 'p75', 'p76', 'p77', 'p78', 'p79', 'p80', 'p81', 'p82', 'p83', 'p84', 'p85', 'p86', 'p87', 'p88', 'p89', 'p90', 'p91', 'p92', 'p93', 'p94', 'p95', 'p96', 'p97', 'p98', 'p99']

# %%
subcorpus = 'Voice of America'

# %% [markdown]
# # Data extraction

# %% [markdown]
# Parsing data from "Voice of America" subcorpus. According to the instructions we take first four columns and additional column to separate data on texts, sentences or words.

# %%
# %%time

voa_data = pd.DataFrame(columns=['word', 'pos', 'lemma', 'ne_tags', 'text_id'])

os.chdir(data_path)
part_paths = os.listdir()

for part_path in tqdm(part_paths, total=len(part_paths)):
    os.chdir(part_path)
    document_paths = os.listdir()
    for document_path in document_paths:
        os.chdir(document_path)
        f = codecs.open("en.met", 'r', "utf_8_sig")
        file_met = f.read()
        if ('subcorpus: {}'.format(subcorpus) in file_met):
            tags_df = pd.read_csv('en.tags',
                                  sep='\t',
                                  header=None,
                                  names=['word', 'pos', 'lemma', 'ne_tags'],
                                  usecols=[0, 1, 2, 3],
                                  error_bad_lines=False)
            tags_df['text_id'] = str(part_path) + '_' + str(document_path)
            voa_data = voa_data.append(tags_df, ignore_index=True)
        f.close()
        os.chdir('..')
    os.chdir('..')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [06:26<00:00,  3.86s/it]
# Wall time: 6min 26s

# %% [markdown]
#    2. one of the character tags T (start of token), S (start of sentence),
#       I (part of token) and O (not part of token)

# %%
from collections import OrderedDict
foo = "mppmtm"
"".join(OrderedDict.fromkeys(foo))
# Out:
# 'mpt'

# %%
test_str = ' '.join(voa_data['ne_tags'].values)
test_str[:1000]
# Out:
# 'O O O O O O geo O O O O O geo O O O O O gpe O O O O O O O O O O O O O O O O O O O O O O [] per O O O [] O [] O O O O [] O O O O O O O O O O O geo geo O O O O O O O O O O O O O O O O O O O O O O O O O O O geo O O org org O O O gpe O O O geo O O O O O O gpe O O O O geo O O O O O O O gpe O O O O O O geo O O O O O O O O O O O O geo O geo O O geo O O org org org org O O O O O O O O geo tim O O O O O gpe O O O O O O O gpe O O O O O O O O O O geo O O O gpe O O O O O O O O O O O O O O tim O O O org O O O O O O O O O O O O O O O O O O org org O O gpe O O O O O O gpe O O org org org O O O O O O O O gpe O O O art art O O gpe O O per per per O tim O gpe O O O O gpe O O O O O O O O O O O gpe O O O gpe O O gpe O O O O O O O O O O O O O O geo O O O geo O O O O O O gpe O org org O per per O O O O O O O O tim O O O O geo geo O geo geo O O O O O O O O org org O O gpe O O O O O O org O O O O O O O O O geo geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O gpe O O O O O O O O O O O '

# %%
import re
test_str_without = re.sub(r'(O |geo |gpe |org |per |tim |gpe |\[\] |art |eve |nat )\1+', r'\1', test_str)
test_str_without[:100]
# Out:
# 'O geo O geo O gpe O [] per O [] O [] O [] O geo O geo O org O gpe O geo O gpe O geo O gpe O geo O ge'

# %%
bio_data = pd.DataFrame(columns=['bio'])
bio_data
# Out:
# Empty DataFrame
# Columns: [bio]
# Index: []

# %%
bio_data.append(pd.DataFrame({'bio': test_str_without.split()}), ignore_index=True)
# Out:
#         bio
# 0         O
# 1       geo
# 2         O
# 3       geo
# 4         O
# ...     ...
# 272265  gpe
# 272266    O
# 272267  per
# 272268    O
# 272269    O
#
# [272270 rows x 1 columns]

# %%
' '.join(voa_data['ne_tags'].values)
# Out:
# 'O O O O O O geo O O O O O geo O O O O O gpe O O O O O O O O O O O O O O O O O O O O O O [] per O O O [] O [] O O O O [] O O O O O O O O O O O geo geo O O O O O O O O O O O O O O O O O O O O O O O O O O O geo O O org org O O O gpe O O O geo O O O O O O gpe O O O O geo O O O O O O O gpe O O O O O O geo O O O O O O O O O O O O geo O geo O O geo O O org org org org O O O O O O O O geo tim O O O O O gpe O O O O O O O gpe O O O O O O O O O O geo O O O gpe O O O O O O O O O O O O O O tim O O O org O O O O O O O O O O O O O O O O O O org org O O gpe O O O O O O gpe O O org org org O O O O O O O O gpe O O O art art O O gpe O O per per per O tim O gpe O O O O gpe O O O O O O O O O O O gpe O O O gpe O O gpe O O O O O O O O O O O O O O geo O O O geo O O O O O O gpe O org org O per per O O O O O O O O tim O O O O geo geo O geo geo O O O O O O O O org org O O gpe O O O O O O org O O O O O O O O O geo geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O gpe O O O O O O O O O O O O O O O O O O O O O O geo O O per per per per O O O O O O O O O O O O O O geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O geo tim O O O O O O O O O O O O O O O O O O O O O gpe O O O O O O O O gpe O O O O O O O O O O O O geo O O O O O org org org org O O O O O O O O O O O O O geo geo O geo O O O O O O O O O O O O O O O O O gpe O O O O O gpe O O O O O O O O O org org org org O O O O O O O O geo O O geo O O O O O geo O O O O O O geo O O O O O O O org O O O O O O O gpe O O O gpe O O O O O O O geo tim O gpe O O O O O O O O O O org org O O O O O O O O O O tim O O O O tim O geo O O O O O org O O O O O O O O O org O O O O O O O O O O O O O O O org org O O O O O O O O O O O O O O O O O O O O tim O O O O O O O O O O O O O O O O O O O O O O O O org org O O O O O O O O O O O O O O O O O O O O O O O O O O geo O geo geo geo geo O O O O O O O O O [] O O [] O O O O O O O O O O O O O O O O O O O O O O org org O O O O O O O O O O O O tim O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O [] O O O [] O O O O O O O O O O O O O O O O O O tim O O O O O O O O O O O O O O O O O O O O O O O O O O O O org O O geo O gpe O O O O O O O O O O O O O O O O O O O O O org O per per O gpe O O tim O per per O O O geo O O O O O O O O O O O org org org O O O O per O O O O O O O O O O O O O O O O O O O O O O O O O org org O O O org org O O O O O O O O O O O O O O O O O O O O O O org O O per O O O O O O O O O O O O O O O O O O O gpe O O O O O O O O O O O O O O O O O O O O O geo O O O O O O O per per per O O O geo geo tim O O O O O O O geo geo O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O gpe O O O O O O O O O O geo geo O O O O O O O O org O org O O O org O O O O geo O tim O O O gpe O O O gpe O O O O O O O [] O O [] O O O O O O O O O O O O O O O O O gpe gpe O O O O gpe O O O O O O O O O per per per O O O O O O O O O O O O O O O O gpe O gpe O gpe gpe O O O O O O O O O O O O O O O O gpe O O O O O O O O O O O O O geo O per O O tim O O O O O O O O O O O O O O O O O O O O O O O geo O O O O O O O O O O O geo O O O O gpe org O O tim O O O O O O O O O O O O org O O O O O O gpe O O geo O O O org O O O O O O O O O O O O O O O O O O O O O O O org O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O org org org org org org org O O O O O O O O O O O org O O O O O O O tim tim O tim O org O per per O O geo O O O O O O O O O org org org O O O O O O O O O O O O O O O O O O O O O org org org org O O O org O per per O O O O O O org org org O O org O O O O O O O O O O O O [] O O O O O O O O O O O O O O O O O O O O O O O O O O O O O [] per O O [] O O O org O O O O O O O O O O O O O O O O O O O O O O O O O O [] org O O O O O O O O O O O O O O O O O O org O O O O O O O O O O O O O O O tim O O O O O O O org O O O O O O O O O O O O O O O org O O O O O O O O O O O O O O O O O O O O O O O O O O O O per O O O org org org O O O org O O O O O O O O O O [] O O O O O O O O O O O O O O O O O O O O O O O O O [] per ...

# %%
# %%time

bio_data = pd.DataFrame(columns=['bio'])

os.chdir(data_path)
part_paths = os.listdir()

for part_path in tqdm(part_paths, total=len(part_paths)):
    os.chdir(part_path)
    document_paths = os.listdir()
    for document_path in document_paths:
        os.chdir(document_path)
        f = codecs.open("en.met", 'r', "utf_8_sig")
        file_met = f.read()
        if ('subcorpus: {}'.format(subcorpus) in file_met):
            bio_df = pd.read_csv('en.tok.iob',
                                 delim_whitespace=True,
                                 header=None,
                                 names=['bio'],
                                 usecols=[1],
                                 error_bad_lines=False)
            #display(bio_df)
            bio_array = bio_df['bio'].values
            #print('bio_array', bio_array)
            bio_str = ' '.join(bio_array)
            #print('bio_str', bio_str)
            bio_str_without_dupl = re.sub(
                r'(S |I |O |T )\1+',
                r'\1', bio_str)
            #print('bio_str_without_dupl', bio_str_without_dupl)
            bio_data = bio_data.append(pd.DataFrame(
                {'bio': bio_str_without_dupl.split()}),
                                       ignore_index=True)
        f.close()
        os.chdir('..')
    os.chdir('..')
# Out:
#   3%|██▍                                                                               | 3/100 [00:05<03:07,  1.93s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# KeyboardInterrupt:

# %%
bio_data.shape
# Out:
# (3451689, 1)

# %%
def show_memory_usage(df):
    print("memory usage: ", df.memory_usage().sum()/1024/1024, " MB")

# %%
show_memory_usage(voa_data)
# Out:
# memory usage:  46.969688415527344  MB

# %%
show_memory_usage(bio_data)
# Out:
# memory usage:  26.33441925048828  MB

# %%
voa_data.head()
# Out:
#             word  pos         lemma ne_tags    text_id
# 0      Thousands  NNS      thousand       O  p00_d0018
# 1             of   IN            of       O  p00_d0018
# 2  demonstrators  NNS  demonstrator       O  p00_d0018
# 3           have  VBP          have       O  p00_d0018
# 4        marched  VBN         march       O  p00_d0018

# %%
voa_data.shape
# Out:
# (1231279, 5)

# %%
bio_data.shape[0] / voa_data.shape[0]
# Out:
# 2.8033362056853077

# %% [markdown]
# Number of tokens coincided with the declared in README file

# %%
voa_data.to_csv('D:\Data\gmb-2.2.0\{}.csv'.format(subcorpus), index=False)

# %%
# %%time

bio_data = pd.DataFrame(columns=['bio'])
voa_data = pd.DataFrame(columns=['word', 'pos', 'lemma', 'ne_tags', 'text_id'])
exit = False

os.chdir(data_path)
part_paths = os.listdir()

for part_path in part_paths:
    os.chdir(part_path)
    document_paths = os.listdir()
    if exit:
        break
    for document_path in document_paths:
        if exit:
            break
        os.chdir(document_path)
        f = codecs.open("en.met", 'r', "utf_8_sig")
        file_met = f.read()
        if ('subcorpus: {}'.format(subcorpus) in file_met):
            print(part_path, document_path)
            bio_df = pd.read_csv('en.tok.iob',
                                 delim_whitespace=True,
                                 header=None,
                                 names=['bio'],
                                 usecols=[1],
                                 error_bad_lines=False)
            #display(bio_df)
            bio_array = bio_df['bio'].values
            #print('bio_array', bio_array)
            bio_str = ' '.join(bio_array)
            #print('bio_str', bio_str)
            bio_str_without_dupl = re.sub(
                r'(S |I |O |T )\1+',
                r'\1', bio_str)
            #print('bio_str_without_dupl', bio_str_without_dupl)
            bio_data = bio_data.append(pd.DataFrame(
                {'bio': bio_array}),#bio_str_without_dupl.split()}),
                                       ignore_index=True)
            
            tags_df = pd.read_csv('en.tags',
                                  sep='\t',
                                  header=None,
                                  names=['word', 'pos', 'lemma', 'ne_tags'],
                                  usecols=[0, 1, 2, 3],
                                  error_bad_lines=False)
            tags_df['text_id'] = str(part_path) + '_' + str(document_path)
            voa_data = voa_data.append(tags_df, ignore_index=True)
            
            exit = True
            
        f.close()
        os.chdir('..')
    os.chdir('..')
# Out:
# p00 d0018
# Wall time: 14 ms

# %%
voa_data.head(2)
# Out:
#         word  pos     lemma ne_tags    text_id
# 0  Thousands  NNS  thousand       O  p00_d0018
# 1         of   IN        of       O  p00_d0018

# %%
len(" ".join(voa_data['word'].values))
# Out:
# 875

# %%
bio_data
# Out:
#     bio
# 0     S
# 1     I
# 2     I
# 3     I
# 4     I
# ..   ..
# 839   I
# 840   I
# 841   I
# 842   T
# 843   O
#
# [844 rows x 1 columns]

# %% [markdown]
# # EDA

# %%
voa_data = pd.read_csv('D:\Data\gmb-2.2.0\{}.csv'.format(subcorpus))
voa_data.head()
# Out:
#             word  pos         lemma ne_tags    text_id
# 0      Thousands  NNS      thousand       O  p00_d0018
# 1             of   IN            of       O  p00_d0018
# 2  demonstrators  NNS  demonstrator       O  p00_d0018
# 3           have  VBP          have       O  p00_d0018
# 4        marched  VBN         march       O  p00_d0018

# %%
def average_text_length(text_id):
    doc_lengths = list(dict(Counter(text_id)).values())
    sum = 0
    for length in doc_lengths:
        sum += length
    return sum/len(doc_lengths)

print("average text length: ", average_text_length(voa_data['text_id']))
# Out:
# average text length:  134.31646121959201

# %%
voa_data.describe()
# Out:
#            word      pos    lemma  ne_tags    text_id
# count   1231279  1231279  1231279  1231279    1231279
# unique    35154       48    27209       25       9167
# top         the       NN      the        O  p00_d0090
# freq      61398   168817    74941  1032479        388

# %%
voa_data['ne_tags'].value_counts()
# Out:
# O          1032479
# geo-nam      55480
# org-nam      44646
# per-nam      22931
# gpe-nam      19685
# tim-dow      11398
# tim-dat      10929
# per-tit       9672
# per-fam       8098
# []            4064
# tim-moy       3811
# tim-yoc       3009
# per-giv       2376
# tim-clo        810
# art-nam        789
# eve-nam        514
# nat-nam        280
# tim-nam        132
# eve-ord         63
# per-ini         55
# per-ord         35
# org-leg         13
# tim-dom          8
# art-add          1
# per-mid          1
# Name: ne_tags, dtype: int64

# %% [markdown]
# # Make BIO

# %% [markdown]
# https://pythonprogramming.net/using-bio-tags-create-named-entity-lists/

# %%
# Tag tokens with standard NLP BIO tags
def bio_tagger(ne_tagged):
		bio_tagged = []
		prev_tag = "O"
		for token, tag in ne_tagged:
			if tag == "O": #O
				bio_tagged.append((token, tag))
				prev_tag = tag
				continue
			if tag != "O" and prev_tag == "O": # Begin NE
				bio_tagged.append((token, "B-"+tag))
				prev_tag = tag
			elif prev_tag != "O" and prev_tag == tag: # Inside NE
				bio_tagged.append((token, "I-"+tag))
				prev_tag = tag
			elif prev_tag != "O" and prev_tag != tag: # Adjacent NE
				bio_tagged.append((token, "B-"+tag))
				prev_tag = tag
		return bio_tagged

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Classificators work better if avoid redundant granularity. Also such detailed fragmentation has no value for the task of only finding named entities. Thus, we can combine subcategories and leave only first part of tag.

# %%
voa_data['ne_tags'] = voa_data['ne_tags'].apply(lambda x: x.split('-')[0])

# %%
voa_data['ne_tags'].value_counts()
# Out:
# O      1032479
# geo      55480
# org      44659
# per      43168
# tim      30097
# gpe      19685
# []        4064
# art        790
# eve        577
# nat        280
# Name: ne_tags, dtype: int64

# %%
voa_data.head()
# Out:
#             word  pos         lemma ne_tags    text_id
# 0      Thousands  NNS      thousand       O  p00_d0018
# 1             of   IN            of       O  p00_d0018
# 2  demonstrators  NNS  demonstrator       O  p00_d0018
# 3           have  VBP          have       O  p00_d0018
# 4        marched  VBN         march       O  p00_d0018

# %% [markdown]
# ## For other models

# %%
voa_data.head(2)
# Out:
#         word  pos     lemma ne_tags    text_id
# 0  Thousands  NNS  thousand       O  p00_d0018
# 1         of   IN        of       O  p00_d0018

# %%
def encode_labels(df, labels_list):
    for label in labels_list:
        le = LabelEncoder()
        df[label] = le.fit_transform(df[label])
    return df

# %%
voa_data = encode_labels(voa_data, ['ne_tags'])

# %%
target = voa_data['ne_tags']
voa_data.drop(['ne_tags', 'text_id'], axis=1, inplace=True)

# %%
voa_data = encode_labels(voa_data, ['word', 'pos', 'lemma'])

# %%
X_train, X_test, y_train, y_test = train_test_split(voa_data, target, test_size = 0.2, shuffle=True, stratify=target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-bd33e2565e3b> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(voa_data, target, test_size = 0.2, shuffle=True, stratify=target)
#
# ~\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2141                      random_state=random_state)
#    2142
# -> 2143         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2144
#    2145     return list(chain.from_iterable((_safe_indexing(a, train),
#
# ~\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    1327         """
#    1328         X, y, groups = indexable(X, y, groups)
# -> 1329         for train, test in self._iter_indices(X, y, groups):
#    1330             yield train, test
#    1331
#
# ~\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_split.py in _iter_indices(self, X, y, groups)
#    1657         class_counts = np.bincount(y_indices)
#    1658         if np.min(class_counts) < 2:
# -> 1659             raise ValueError("The least populated class in y has only 1"
#    1660                              " member, which is too few. The minimum"
#    1661                              " number of groups for any class cannot"
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %% [markdown]
# ## For CRF

# %%
def get_sentences(df):
    """func to get the sentences in this format:
    [(Token_1, Part_of_Speech_1, Tag_1), ..., (Token_n, Part_of_Speech_n, Tag_n)]"""
    
    agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["word"].values.tolist(),
                                                       s["pos"].values.tolist(),
                                                       s["ne_tags"].values.tolist())]
    grouped = df.groupby("text_id").apply(agg_func)
    sentences = [s for s in grouped]
    
    return sentences

# %%
# %%time

word_pos_tag_sentences = get_sentences(voa_data)
display(word_pos_tag_sentences[:2])
# Out:
# [[('Thousands', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('demonstrators', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('marched', 'VBN', 'O'),
#   ('through', 'IN', 'O'),
#   ('London', 'NNP', 'geo-nam'),
#   ('to', 'TO', 'O'),
#   ('protest', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('war', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Iraq', 'NNP', 'geo-nam'),
#   ('and', 'CC', 'O'),
#   ('demand', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('withdrawal', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('British', 'JJ', 'gpe-nam'),
#   ('troops', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('that', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('.', '.', 'O'),
#   ('Families', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('soldiers', 'NNS', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('conflict', 'NN', 'O'),
#   ('joined', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('protesters', 'NNS', 'O'),
#   ('who', 'WP', 'O'),
#   ('carried', 'VBD', 'O'),
#   ('banners', 'NNS', 'O'),
#   ('with', 'IN', 'O'),
#   ('such', 'JJ', 'O'),
#   ('slogans', 'NNS', 'O'),
#   ('as', 'IN', 'O'),
#   ('\tLQU\t', 'O', '[]'),
#   ('Bush', 'NNP', 'per-fam'),
#   ('Number', 'NN', 'O'),
#   ('One', 'CD', 'O'),
#   ('Terrorist', 'NN', 'O'),
#   ('\tRQU\t', 'O', '[]'),
#   ('and', 'CC', 'O'),
#   ('\tLQU\t', 'O', '[]'),
#   ('Stop', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('Bombings', 'NNS', 'O'),
#   ('.', '.', 'O'),
#   ('\tLQU\t', 'O', '[]'),
#   ('They', 'PRP', 'O'),
#   ('marched', 'VBD', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Houses', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('Parliament', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('a', 'DT', 'O'),
#   ('rally', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Hyde', 'NNP', 'geo-nam'),
#   ('Park', 'NNP', 'geo-nam'),
#   ('.', '.', 'O'),
#   ('Police', 'NNS', 'O'),
#   ('put', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('number', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('marchers', 'NNS', 'O'),
#   ('at', 'IN', 'O'),
#   ('10,000', 'CD', 'O'),
#   ('while', 'IN', 'O'),
#   ('organizers', 'NNS', 'O'),
#   ('claimed', 'VBD', 'O'),
#   ('it', 'PRP', 'O'),
#   ('was', 'VBD', 'O'),
#   ('100,000', 'CD', 'O'),
#   ('.', '.', 'O'),
#   ('The', 'DT', 'O'),
#   ('protest', 'NN', 'O'),
#   ('comes', 'VBZ', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('eve', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('annual', 'JJ', 'O'),
#   ('conference', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Britain', 'NNP', 'geo-nam'),
#   ("'s", 'POS', 'O'),
#   ('ruling', 'VBG', 'O'),
#   ('Labor', 'NNP', 'org-nam'),
#   ('Party', 'NNP', 'org-nam'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('southern', 'JJ', 'O'),
#   ('English', 'JJ', 'gpe-nam'),
#   ('seaside', 'NN', 'O'),
#   ('resort', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Brighton', 'NNP', 'geo-nam'),
#   ('.', '.', 'O'),
#   ('The', 'DT', 'O'),
#   ('party', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('divided', 'VBN', 'O'),
#   ('over', 'IN', 'O'),
#   ('Britain', 'NNP', 'gpe-nam'),
#   ("'s", 'POS', 'O'),
#   ('participation', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Iraq', 'NNP', 'geo-nam'),
#   ('conflict', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('continued', 'JJ', 'O'),
#   ('deployment', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('8,500', 'CD', 'O'),
#   ('British', 'JJ', 'gpe-nam'),
#   ('troops', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('that', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('.', '.', 'O'),
#   ('The', 'DT', 'O'),
#   ('London', 'NNP', 'geo-nam'),
#   ('march', 'NN', 'O'),
#   ('came', 'VBD', 'O'),
#   ('ahead', 'RB', 'O'),
#   ('of', 'IN', 'O'),
#   ('anti-war', 'JJ', 'O'),
#   ('protests', 'NNS', 'O'),
#   ('today', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('other', 'JJ', 'O'),
#   ('cities', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('including', 'VBG', 'O'),
#   ('Rome', 'NNP', 'geo-nam'),
#   (',', ',', 'O'),
#   ('Paris', 'NNP', 'geo-nam'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('Madrid', 'NNP', 'geo-nam'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('International', 'NNP', 'org-nam'),
#   ('Atomic', 'NNP', 'org-nam'),
#   ('Energy', 'NNP', 'org-nam'),
#   ('Agency', 'NNP', 'org-nam'),
#   ('is', 'VBZ', 'O'),
#   ('to', 'TO', 'O'),
#   ('hold', 'VB', 'O'),
#   ('second', 'JJ', 'O'),
#   ('day', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('talks', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Vienna', 'NNP', 'geo-nam'),
#   ('Wednesday', 'NNP', 'tim-dow'),
#   ('on', 'IN', 'O'),
#   ('how', 'WRB', 'O'),
#   ('to', 'TO', 'O'),
#   ('respond', 'VB', 'O'),
#   ('to', 'TO', 'O'),
#   ('Iran', 'NNP', 'gpe-nam'),
#   ("'s", 'POS', 'O'),
#   ('resumption', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('low-level', 'JJ', 'O'),
#   ('uranium', 'NN', 'O'),
#   ('conversion', 'NN', 'O'),
#   ('.', '.', 'O'),
#   ('Iran', 'NNP', 'gpe-nam'),
#   ('this', 'DT', 'O'),
#   ('week', 'NN', 'O'),
#   ('restarted', 'VBD', 'O'),
#   ('parts', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('conversion', 'NN', 'O'),
#   ('process', 'NN', 'O'),
#   ('at', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('Isfahan', 'NNP', 'geo-nam'),
#   ('nuclear', 'JJ', 'O'),
#   ('plant', 'NN', 'O'),
#   ('.', '.', 'O'),
#   ('Iranian', 'JJ', 'gpe-nam'),
#   ('officials', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('they', 'PRP', 'O'),
#   ('expect', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('get', 'VB', 'O'),
#   ('access', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('sealed', 'JJ', 'O'),
#   ('sensitive', 'JJ', 'O'),
#   ('parts', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('plant', 'NN', 'O'),
#   ('Wednesday', 'NNP', 'tim-dow'),
#   (',', ',', 'O'),
#   ('after', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('IAEA', 'NNP', 'org-nam'),
#   ('surveillance', 'NN', 'O'),
#   ('system', 'NN', 'O'),
#   ('begins', 'VBZ', 'O'),
#   ('functioning', 'VBG', 'O'),
#   ('.', '.', 'O'),
#   ('The', 'DT', 'O'),
#   ('step', 'NN', 'O'),
#   ('will', 'MD', 'O'),
#   ('allow', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('facility', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('operate', 'VB', 'O'),
#   ('at', 'IN', 'O'),
#   ('full', 'JJ', 'O'),
#   ('capacity', 'NN', 'O'),
#   ('.', '.', 'O'),
#   ('The', 'DT', 'O'),
#   ('European', 'NNP', 'org-nam'),
#   ('Union', 'NNP', 'org-nam'),
#   (',', ',', 'O'),
#   ('with', 'IN', 'O'),
#   ('U.S.', 'NNP', 'gpe-nam'),
#   ('backing', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('threatened', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('refer', 'VB', 'O'),
#   ('Iran', 'NNP', 'gpe-nam'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('U.N.', 'NNP', 'org-nam'),
#   ('Security', 'NNP', 'org-nam'),
#   ('Council', 'NNP', 'org-nam'),
#   (',', ',', 'O'),
#   ('which', 'WDT', 'O'),
#   ('could', 'MD', 'O'),
#   ('impose', 'VB', 'O'),
#   ('sanctions', 'NNS', 'O'),
#   ('if', 'IN', 'O'),
#   ('it', 'PRP', 'O'),
#   ('finds', 'VBZ', 'O'),
#   ('Tehran', 'NNP', 'gpe-nam'),
#   ('has', 'VBZ', 'O'),
#   ('violated', 'VBN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Nuclear', 'NNP', 'art-nam'),
#   ('Non-Proliferation', 'NNP', 'art-nam'),
#   ('treaty', 'NN', 'O'),
#   ('.', '.', 'O'),
#   ('Iran', 'NNP', 'gpe-nam'),
#   ("'s", 'POS', 'O'),
#   ('new', 'JJ', 'O'),
#   ('President', 'NNP', 'per-tit'),
#   ('Mahmoud', 'NNP', 'per-giv'),
#   ('Ahmadinejad', 'NNP', 'per-fam'),
#   ('said', 'VBD', 'O'),
#   ('Tuesday', 'NNP', 'tim-dow'),
#   ('that', 'IN', 'O'),
#   ('European', 'JJ', 'gpe-nam'),
#   ('incentives', 'NNS', 'O'),
#   ('aimed', 'VBN', 'O'),
#   ('at', 'IN', 'O'),
#   ('persuading', 'VBG', 'O'),
#   ('Iran', 'NNP', 'gpe-nam'),
#   ('to', 'TO', 'O'),
#   ('end', 'VB', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('nuclear', 'JJ', 'O'),
#   ('fuel', 'NN', 'O'),
#   ('program', 'NN', 'O'),
#   ('are', 'VBP', 'O'),
#   ('an', 'DT', 'O'),
#   ('insult', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('Iranian', 'JJ', 'gpe-nam'),
#   ('nation', 'NN', 'O'),
#   ('.', '.', 'O')]]
# Wall time: 1.55 s

# %%
#Lets visualize how the sentences are distributed by their length
plt.style.use("ggplot")
plt.hist([len(s) for s in word_pos_tag_sentences], bins=50)
plt.show()

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:], #replace with BPE
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def get_sent_labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %% [markdown]
# ### Split

# %%
len(word_pos_tag_sentences)
# Out:
# 9167

# %%
X = [sent2features(s) for s in word_pos_tag_sentences]
y = [get_sent_labels(s) for s in word_pos_tag_sentences]

# %%
X[:2]
# Out:
# [[{'bias': 1.0,
#    'word.lower()': 'thousands',
#    'word[-3:]': 'nds',
#    'word[-2:]': 'ds',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    'BOS': True,
#    '+1:word.lower()': 'of',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'of',
#    'word[-3:]': 'of',
#    'word[-2:]': 'of',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'thousands',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'demonstrators',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'demonstrators',
#    'word[-3:]': 'ors',
#    'word[-2:]': 'rs',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'of',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'have',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBP',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'have',
#    'word[-3:]': 'ave',
#    'word[-2:]': 've',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBP',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'demonstrators',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'marched',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBN',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'marched',
#    'word[-3:]': 'hed',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBN',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'have',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBP',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'through',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'through',
#    'word[-3:]': 'ugh',
#    'word[-2:]': 'gh',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'marched',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBN',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'london',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'london',
#    'word[-3:]': 'don',
#    'word[-2:]': 'on',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'through',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'to',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TO',
#    '+1:postag[:2]': 'TO'},
#   {'bias': 1.0,
#    'word.lower()': 'to',
#    'word[-3:]': 'to',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TO',
#    'postag[:2]': 'TO',
#    '-1:word.lower()': 'london',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'protest',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VB',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'protest',
#    'word[-3:]': 'est',
#    'word[-2:]': 'st',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VB',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'to',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TO',
#    '-1:postag[:2]': 'TO',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'protest',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VB',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'war',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'war',
#    'word[-3:]': 'war',
#    'word[-2:]': 'ar',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'in',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'in',
#    'word[-3:]': 'in',
#    'word[-2:]': 'in',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'war',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'iraq',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'iraq',
#    'word[-3:]': 'raq',
#    'word[-2:]': 'aq',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'in',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'and',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CC',
#    '+1:postag[:2]': 'CC'},
#   {'bias': 1.0,
#    'word.lower()': 'and',
#    'word[-3:]': 'and',
#    'word[-2:]': 'nd',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CC',
#    'postag[:2]': 'CC',
#    '-1:word.lower()': 'iraq',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'demand',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VB',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'demand',
#    'word[-3:]': 'and',
#    'word[-2:]': 'nd',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VB',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'and',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CC',
#    '-1:postag[:2]': 'CC',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'demand',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VB',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'withdrawal',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'withdrawal',
#    'word[-3:]': 'wal',
#    'word[-2:]': 'al',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'of',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'of',
#    'word[-3:]': 'of',
#    'word[-2:]': 'of',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'withdrawal',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'british',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'JJ',
#    '+1:postag[:2]': 'JJ'},
#   {'bias': 1.0,
#    'word.lower()': 'british',
#    'word[-3:]': 'ish',
#    'word[-2:]': 'sh',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'JJ',
#    'postag[:2]': 'JJ',
#    '-1:word.lower()': 'of',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'troops',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'troops',
#    'word[-3:]': 'ops',
#    'word[-2:]': 'ps',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'british',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'JJ',
#    '-1:postag[:2]': 'JJ',
#    '+1:word.lower()': 'from',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'from',
#    'word[-3:]': 'rom',
#    'word[-2:]': 'om',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'troops',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'that',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'that',
#    'word[-3:]': 'hat',
#    'word[-2:]': 'at',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'from',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'country',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'country',
#    'word[-3:]': 'try',
#    'word[-2:]': 'ry',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'that',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': '.',
#    '+1:postag[:2]': '.'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': '.',
#    'postag[:2]': '.',
#    '-1:word.lower()': 'country',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'families',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'families',
#    'word[-3:]': 'ies',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': '.',
#    '-1:postag[:2]': '.',
#    '+1:word.lower()': 'of',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'of',
#    'word[-3:]': 'of',
#    'word[-2:]': 'of',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'families',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'soldiers',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'soldiers',
#    'word[-3:]': 'ers',
#    'word[-2:]': 'rs',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'of',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'killed',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBN',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'killed',
#    'word[-3:]': 'led',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBN',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'soldiers',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'in',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'in',
#    'word[-3:]': 'in',
#    'word[-2:]': 'in',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'killed',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBN',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'in',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'conflict',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'conflict',
#    'word[-3:]': 'ict',
#    'word[-2:]': 'ct',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'joined',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBD',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'joined',
#    'word[-3:]': 'ned',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBD',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'conflict',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'joined',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBD',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'protesters',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'protesters',
#    'word[-3:]': 'ers',
#    'word[-2:]': 'rs',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'who',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'WP',
#    '+1:postag[:2]': 'WP'},
#   {'bias': 1.0,
#    'word.lower()': 'who',
#    'word[-3:]': 'who',
#    'word[-2:]': 'ho',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'WP',
#    'postag[:2]': 'WP',
#    '-1:word.lower()': 'protesters',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'carried',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBD',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'carried',
#    'word[-3:]': 'ied',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBD',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'who',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'WP',
#    '-1:postag[:2]': 'WP',
#    '+1:word.lower()': 'banners',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'banners',
#    'word[-3:]': 'ers',
#    'word[-2:]': 'rs',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'carried',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBD',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'with',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'with',
#    'word[-3:]': 'ith',
#    'word[-2:]': 'th',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'banners',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'such',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'JJ',
#    '+1:postag[:2]': 'JJ'},
#   {'bias': 1.0,
#    'word.lower()': 'such',
#    'word[-3:]': 'uch',
#    'word[-2:]': 'ch',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'JJ',
#    'postag[:2]': 'JJ',
#    '-1:word.lower()': 'with',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'slogans',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'slogans',
#    'word[-3:]': 'ans',
#    'word[-2:]': 'ns',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'such',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'JJ',
#    '-1:postag[:2]': 'JJ',
#    '+1:word.lower()': 'as',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'as',
#    'word[-3:]': 'as',
#    'word[-2:]': 'as',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'slogans',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': '\tlqu\t',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': True,
#    '+1:postag': 'O',
#    '+1:postag[:2]': 'O'},
#   {'bias': 1.0,
#    'word.lower()': '\tlqu\t',
#    'word[-3:]': 'QU\t',
#    'word[-2:]': 'U\t',
#    'word.isupper()': True,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'O',
#    'postag[:2]': 'O',
#    '-1:word.lower()': 'as',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'bush',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'bush',
#    'word[-3:]': 'ush',
#    'word[-2:]': 'sh',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': '\tlqu\t',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': True,
#    '-1:postag': 'O',
#    '-1:postag[:2]': 'O',
#    '+1:word.lower()': 'number',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'number',
#    'word[-3:]': 'ber',
#    'word[-2:]': 'er',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'bush',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'one',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CD',
#    '+1:postag[:2]': 'CD'},
#   {'bias': 1.0,
#    'word.lower()': 'one',
#    'word[-3:]': 'One',
#    'word[-2:]': 'ne',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'CD',
#    'postag[:2]': 'CD',
#    '-1:word.lower()': 'number',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'terrorist',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'terrorist',
#    'word[-3:]': 'ist',
#    'word[-2:]': 'st',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'one',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CD',
#    '-1:postag[:2]': 'CD',
#    '+1:word.lower()': '\trqu\t',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': True,
#    '+1:postag': 'O',
#    '+1:postag[:2]': 'O'},
#   {'bias': 1.0,
#    'word.lower()': '\trqu\t',
#    'word[-3:]': 'QU\t',
#    'word[-2:]': 'U\t',
#    'word.isupper()': True,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'O',
#    'postag[:2]': 'O',
#    '-1:word.lower()': 'terrorist',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'and',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CC',
#    '+1:postag[:2]': 'CC'},
#   {'bias': 1.0,
#    'word.lower()': 'and',
#    'word[-3:]': 'and',
#    'word[-2:]': 'nd',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CC',
#    'postag[:2]': 'CC',
#    '-1:word.lower()': '\trqu\t',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': True,
#    '-1:postag': 'O',
#    '-1:postag[:2]': 'O',
#    '+1:word.lower()': '\tlqu\t',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': True,
#    '+1:postag': 'O',
#    '+1:postag[:2]': 'O'},
#   {'bias': 1.0,
#    'word.lower()': '\tlqu\t',
#    'word[-3:]': 'QU\t',
#    'word[-2:]': 'U\t',
#    'word.isupper()': True,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'O',
#    'postag[:2]': 'O',
#    '-1:word.lower()': 'and',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CC',
#    '-1:postag[:2]': 'CC',
#    '+1:word.lower()': 'stop',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VB',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'stop',
#    'word[-3:]': 'top',
#    'word[-2:]': 'op',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'VB',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': '\tlqu\t',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': True,
#    '-1:postag': 'O',
#    '-1:postag[:2]': 'O',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'stop',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VB',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'bombings',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'bombings',
#    'word[-3:]': 'ngs',
#    'word[-2:]': 'gs',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': '.',
#    '+1:postag[:2]': '.'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': '.',
#    'postag[:2]': '.',
#    '-1:word.lower()': 'bombings',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': '\tlqu\t',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': True,
#    '+1:postag': 'O',
#    '+1:postag[:2]': 'O'},
#   {'bias': 1.0,
#    'word.lower()': '\tlqu\t',
#    'word[-3:]': 'QU\t',
#    'word[-2:]': 'U\t',
#    'word.isupper()': True,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'O',
#    'postag[:2]': 'O',
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': '.',
#    '-1:postag[:2]': '.',
#    '+1:word.lower()': 'they',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PRP',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'they',
#    'word[-3:]': 'hey',
#    'word[-2:]': 'ey',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'PRP',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': '\tlqu\t',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': True,
#    '-1:postag': 'O',
#    '-1:postag[:2]': 'O',
#    '+1:word.lower()': 'marched',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBD',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'marched',
#    'word[-3:]': 'hed',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBD',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'they',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PRP',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'from',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'from',
#    'word[-3:]': 'rom',
#    'word[-2:]': 'om',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'marched',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBD',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'from',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'houses',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'houses',
#    'word[-3:]': 'ses',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'of',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'of',
#    'word[-3:]': 'of',
#    'word[-2:]': 'of',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'houses',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'parliament',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'parliament',
#    'word[-3:]': 'ent',
#    'word[-2:]': 'nt',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'of',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'to',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TO',
#    '+1:postag[:2]': 'TO'},
#   {'bias': 1.0,
#    'word.lower()': 'to',
#    'word[-3:]': 'to',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TO',
#    'postag[:2]': 'TO',
#    '-1:word.lower()': 'parliament',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'a',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'a',
#    'word[-3:]': 'a',
#    'word[-2:]': 'a',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'to',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TO',
#    '-1:postag[:2]': 'TO',
#    '+1:word.lower()': 'rally',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'rally',
#    'word[-3:]': 'lly',
#    'word[-2:]': 'ly',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'a',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'in',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'in',
#    'word[-3:]': 'in',
#    'word[-2:]': 'in',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'rally',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'hyde',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'hyde',
#    'word[-3:]': 'yde',
#    'word[-2:]': 'de',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'in',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'park',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'park',
#    'word[-3:]': 'ark',
#    'word[-2:]': 'rk',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'hyde',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': '.',
#    '+1:postag[:2]': '.'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': '.',
#    'postag[:2]': '.',
#    '-1:word.lower()': 'park',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'police',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'police',
#    'word[-3:]': 'ice',
#    'word[-2:]': 'ce',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': '.',
#    '-1:postag[:2]': '.',
#    '+1:word.lower()': 'put',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBD',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'put',
#    'word[-3:]': 'put',
#    'word[-2:]': 'ut',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBD',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'police',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'put',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBD',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'number',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'number',
#    'word[-3:]': 'ber',
#    'word[-2:]': 'er',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'of',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'of',
#    'word[-3:]': 'of',
#    'word[-2:]': 'of',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'number',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'marchers',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'marchers',
#    'word[-3:]': 'ers',
#    'word[-2:]': 'rs',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'of',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'at',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'at',
#    'word[-3:]': 'at',
#    'word[-2:]': 'at',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'marchers',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': '10,000',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CD',
#    '+1:postag[:2]': 'CD'},
#   {'bias': 1.0,
#    'word.lower()': '10,000',
#    'word[-3:]': '000',
#    'word[-2:]': '00',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CD',
#    'postag[:2]': 'CD',
#    '-1:word.lower()': 'at',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'while',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'while',
#    'word[-3:]': 'ile',
#    'word[-2:]': 'le',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': '10,000',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CD',
#    '-1:postag[:2]': 'CD',
#    '+1:word.lower()': 'organizers',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'organizers',
#    'word[-3:]': 'ers',
#    'word[-2:]': 'rs',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'while',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'claimed',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBD',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'claimed',
#    'word[-3:]': 'med',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBD',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'organizers',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'it',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PRP',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'it',
#    'word[-3:]': 'it',
#    'word[-2:]': 'it',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PRP',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'claimed',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBD',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'was',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBD',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'was',
#    'word[-3:]': 'was',
#    'word[-2:]': 'as',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBD',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'it',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PRP',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': '100,000',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CD',
#    '+1:postag[:2]': 'CD'},
#   {'bias': 1.0,
#    'word.lower()': '100,000',
#    'word[-3:]': '000',
#    'word[-2:]': '00',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CD',
#    'postag[:2]': 'CD',
#    '-1:word.lower()': 'was',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBD',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': '.',
#    '+1:postag[:2]': '.'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': '.',
#    'postag[:2]': '.',
#    '-1:word.lower()': '100,000',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CD',
#    '-1:postag[:2]': 'CD',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'The',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': '.',
#    '-1:postag[:2]': '.',
#    '+1:word.lower()': 'protest',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'protest',
#    'word[-3:]': 'est',
#    'word[-2:]': 'st',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'comes',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBZ',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'comes',
#    'word[-3:]': 'mes',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBZ',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'protest',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'on',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'on',
#    'word[-3:]': 'on',
#    'word[-2:]': 'on',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'comes',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBZ',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'on',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'eve',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'eve',
#    'word[-3:]': 'eve',
#    'word[-2:]': 've',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'of',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'of',
#    'word[-3:]': 'of',
#    'word[-2:]': 'of',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'eve',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'of',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'annual',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'JJ',
#    '+1:postag[:2]': 'JJ'},
#   {'bias': 1.0,
#    'word.lower()': 'annual',
#    'word[-3:]': 'ual',
#    'word[-2:]': 'al',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'JJ',
#    'postag[:2]': 'JJ',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'conference',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'conference',
#    'word[-3:]': 'nce',
#    'word[-2:]': 'ce',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'annual',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'JJ',
#    '-1:postag[:2]': 'JJ',
#    '+1:word.lower()': 'of',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'of',
#    'word[-3:]': 'of',
#    'word[-2:]': 'of',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'conference',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'britain',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'britain',
#    'word[-3:]': 'ain',
#    'word[-2:]': 'in',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'of',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': "'s",
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'POS',
#    '+1:postag[:2]': 'PO'},
#   {'bias': 1.0,
#    'word.lower()': "'s",
#    'word[-3:]': "'s",
#    'word[-2:]': "'s",
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'POS',
#    'postag[:2]': 'PO',
#    '-1:word.lower()': 'britain',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'ruling',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBG',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'ruling',
#    'word[-3:]': 'ing',
#    'word[-2:]': 'ng',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBG',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': "'s",
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'POS',
#    '-1:postag[:2]': 'PO',
#    '+1:word.lower()': 'labor',
# ...
#    '+1:word.lower()': 'non-proliferation',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'non-proliferation',
#    'word[-3:]': 'ion',
#    'word[-2:]': 'on',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'nuclear',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'treaty',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'treaty',
#    'word[-3:]': 'aty',
#    'word[-2:]': 'ty',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'non-proliferation',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': '.',
#    '+1:postag[:2]': '.'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': '.',
#    'postag[:2]': '.',
#    '-1:word.lower()': 'treaty',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'iran',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'iran',
#    'word[-3:]': 'ran',
#    'word[-2:]': 'an',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': '.',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': '.',
#    '-1:postag[:2]': '.',
#    '+1:word.lower()': "'s",
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'POS',
#    '+1:postag[:2]': 'PO'},
#   {'bias': 1.0,
#    'word.lower()': "'s",
#    'word[-3:]': "'s",
#    'word[-2:]': "'s",
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'POS',
#    'postag[:2]': 'PO',
#    '-1:word.lower()': 'iran',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'new',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'JJ',
#    '+1:postag[:2]': 'JJ'},
#   {'bias': 1.0,
#    'word.lower()': 'new',
#    'word[-3:]': 'new',
#    'word[-2:]': 'ew',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'JJ',
#    'postag[:2]': 'JJ',
#    '-1:word.lower()': "'s",
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'POS',
#    '-1:postag[:2]': 'PO',
#    '+1:word.lower()': 'president',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'president',
#    'word[-3:]': 'ent',
#    'word[-2:]': 'nt',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'new',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'JJ',
#    '-1:postag[:2]': 'JJ',
#    '+1:word.lower()': 'mahmoud',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'mahmoud',
#    'word[-3:]': 'oud',
#    'word[-2:]': 'ud',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'president',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'ahmadinejad',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'ahmadinejad',
#    'word[-3:]': 'jad',
#    'word[-2:]': 'ad',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'mahmoud',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'said',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBD',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'said',
#    'word[-3:]': 'aid',
#    'word[-2:]': 'id',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBD',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'ahmadinejad',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'tuesday',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'tuesday',
#    'word[-3:]': 'day',
#    'word[-2:]': 'ay',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'said',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBD',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'that',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'that',
#    'word[-3:]': 'hat',
#    'word[-2:]': 'at',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'tuesday',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'european',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'JJ',
#    '+1:postag[:2]': 'JJ'},
#   {'bias': 1.0,
#    'word.lower()': 'european',
#    'word[-3:]': 'ean',
#    'word[-2:]': 'an',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'JJ',
#    'postag[:2]': 'JJ',
#    '-1:word.lower()': 'that',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'incentives',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNS',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'incentives',
#    'word[-3:]': 'ves',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NNS',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'european',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'JJ',
#    '-1:postag[:2]': 'JJ',
#    '+1:word.lower()': 'aimed',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBN',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'aimed',
#    'word[-3:]': 'med',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBN',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'incentives',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNS',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'at',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'IN',
#    '+1:postag[:2]': 'IN'},
#   {'bias': 1.0,
#    'word.lower()': 'at',
#    'word[-3:]': 'at',
#    'word[-2:]': 'at',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'IN',
#    'postag[:2]': 'IN',
#    '-1:word.lower()': 'aimed',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBN',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'persuading',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBG',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'persuading',
#    'word[-3:]': 'ing',
#    'word[-2:]': 'ng',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBG',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'at',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'IN',
#    '-1:postag[:2]': 'IN',
#    '+1:word.lower()': 'iran',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NNP',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'iran',
#    'word[-3:]': 'ran',
#    'word[-2:]': 'an',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'NNP',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'persuading',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBG',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'to',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TO',
#    '+1:postag[:2]': 'TO'},
#   {'bias': 1.0,
#    'word.lower()': 'to',
#    'word[-3:]': 'to',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TO',
#    'postag[:2]': 'TO',
#    '-1:word.lower()': 'iran',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NNP',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'end',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VB',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'end',
#    'word[-3:]': 'end',
#    'word[-2:]': 'nd',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VB',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'to',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TO',
#    '-1:postag[:2]': 'TO',
#    '+1:word.lower()': 'its',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PRP$',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'its',
#    'word[-3:]': 'its',
#    'word[-2:]': 'ts',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PRP$',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'end',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VB',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'nuclear',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'JJ',
#    '+1:postag[:2]': 'JJ'},
#   {'bias': 1.0,
#    'word.lower()': 'nuclear',
#    'word[-3:]': 'ear',
#    'word[-2:]': 'ar',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'JJ',
#    'postag[:2]': 'JJ',
#    '-1:word.lower()': 'its',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PRP$',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'fuel',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'fuel',
#    'word[-3:]': 'uel',
#    'word[-2:]': 'el',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'nuclear',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'JJ',
#    '-1:postag[:2]': 'JJ',
#    '+1:word.lower()': 'program',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'program',
#    'word[-3:]': 'ram',
#    'word[-2:]': 'am',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'fuel',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'are',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'VBP',
#    '+1:postag[:2]': 'VB'},
#   {'bias': 1.0,
#    'word.lower()': 'are',
#    'word[-3:]': 'are',
#    'word[-2:]': 're',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'VBP',
#    'postag[:2]': 'VB',
#    '-1:word.lower()': 'program',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'an',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'an',
#    'word[-3:]': 'an',
#    'word[-2:]': 'an',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'are',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'VBP',
#    '-1:postag[:2]': 'VB',
#    '+1:word.lower()': 'insult',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'insult',
#    'word[-3:]': 'ult',
#    'word[-2:]': 'lt',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'an',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'to',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TO',
#    '+1:postag[:2]': 'TO'},
#   {'bias': 1.0,
#    'word.lower()': 'to',
#    'word[-3:]': 'to',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TO',
#    'postag[:2]': 'TO',
#    '-1:word.lower()': 'insult',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'DT',
#    '+1:postag[:2]': 'DT'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'DT',
#    'postag[:2]': 'DT',
#    '-1:word.lower()': 'to',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TO',
#    '-1:postag[:2]': 'TO',
#    '+1:word.lower()': 'iranian',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'JJ',
#    '+1:postag[:2]': 'JJ'},
#   {'bias': 1.0,
#    'word.lower()': 'iranian',
#    'word[-3:]': 'ian',
#    'word[-2:]': 'an',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'JJ',
#    'postag[:2]': 'JJ',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'DT',
#    '-1:postag[:2]': 'DT',
#    '+1:word.lower()': 'nation',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'NN',
#    '+1:postag[:2]': 'NN'},
#   {'bias': 1.0,
#    'word.lower()': 'nation',
#    'word[-3:]': 'ion',
#    'word[-2:]': 'on',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'NN',
#    'postag[:2]': 'NN',
#    '-1:word.lower()': 'iranian',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'JJ',
#    '-1:postag[:2]': 'JJ',
#    '+1:word.lower()': '.',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': '.',
#    '+1:postag[:2]': '.'},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'word[-2:]': '.',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': '.',
#    'postag[:2]': '.',
#    '-1:word.lower()': 'nation',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'NN',
#    '-1:postag[:2]': 'NN',
#    'EOS': True}]]

# %%
ne_tags = voa_data['ne_tags'].unique()
ne_tags
# Out:
# array(['O', 'geo-nam', 'gpe-nam', '[]', 'per-fam', 'org-nam', 'tim-dow',
#        'art-nam', 'per-tit', 'per-giv', 'per-nam', 'tim-yoc', 'tim-moy',
#        'tim-dom', 'tim-dat', 'tim-nam', 'nat-nam', 'eve-ord', 'eve-nam',
#        'tim-clo', 'per-ord', 'per-ini', 'org-leg', 'per-mid', 'art-add'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(y[:2])

le.classes_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     104         try:
# --> 105             res = _encode_python(values, uniques, encode)
#     106         except TypeError:
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\preprocessing\label.py in _encode_python(values, uniques, encode)
#      58     if uniques is None:
# ---> 59         uniques = sorted(set(values))
#      60         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-fd41bf743dd6> in <module>
#       1 from sklearn.preprocessing import LabelEncoder
#       2 le = LabelEncoder()
# ----> 3 le.fit(y[:2])
#       4
#       5 le.classes_
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\preprocessing\label.py in fit(self, y)
#     218         """
#     219         y = column_or_1d(y, warn=True)
# --> 220         self.classes_ = _encode(y)
#     221         return self
#     222
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     105             res = _encode_python(values, uniques, encode)
#     106         except TypeError:
# --> 107             raise TypeError("argument must be a string or number")
#     108         return res
#     109     else:
#
# TypeError: argument must be a string or number

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=True)

# %% [markdown]
# # Training model

# %%
from sklearn.metrics import make_scorer, roc_auc_score
scoring = make_scorer(roc_auc_score, needs_proba=True, average='weighted', multi_class='ovr')
cv = ShuffleSplit(n_splits=1, test_size=0.3, random_state=42)

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB

# %% [markdown]
# ### Bernoulli

# %%
X_train.head(2)
# Out:
#          word  pos  lemma
# 365118     23    2     16
# 430144  27891   10  18001

# %%
bernoulliCLF = RandomForestClassifier()

bernoulliCLF.fit(X_train, y_train)

y_pred = bernoulliCLF.predict(X_test)
y_pred

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99    206238
#            1       1.00      1.00      1.00       804
#            3       0.37      0.15      0.22       168
#            4       0.38      0.14      0.20        95
#            5       0.41      0.82      0.55        11
#            6       0.81      0.87      0.84     11266
#            7       0.99      0.94      0.96      3966
#            8       0.63      0.58      0.61        57
#            9       1.00      0.33      0.50         3
#           10       0.76      0.64      0.70      8913
#           11       0.88      0.90      0.89      1648
#           12       0.86      0.79      0.82       514
#           13       0.80      0.89      0.84         9
#           14       0.00      0.00      0.00         1
#           15       0.75      0.78      0.76      4612
#           16       0.00      0.00      0.00        11
#           17       0.92      0.96      0.94      1962
#           18       0.78      0.39      0.52       173
#           19       0.64      0.24      0.35      2117
#           20       0.00      0.00      0.00         1
#           21       0.99      1.00      1.00      2331
#           22       0.99      1.00      0.99       757
#           23       0.00      0.00      0.00        23
#           24       0.98      0.99      0.99       576
#
#     accuracy                           0.96    246256
#    macro avg       0.66      0.60      0.61    246256
# weighted avg       0.96      0.96      0.96    246256
# C:\Users\Oleg\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
scores = cross_validate(BernoulliNB(), X_train, y_train, cv=cv, n_jobs=-1, 
                        scoring=scoring, verbose=100)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Pickling array (shape=(3,), dtype=object).
# Memmapping (shape=(985023,), dtype=int64) to new file C:\Users\Oleg\AppData\Local\Temp\joblib_memmapping_folder_23576_9312356208\23576-1560074912544-306ce5811dbb4b66b62623150468230d.pkl
# Memmapping (shape=(3, 985023), dtype=int32) to new file C:\Users\Oleg\AppData\Local\Temp\joblib_memmapping_folder_23576_9312356208\23576-1560074912544-4f49efd3a67244c6b96efdb9249fc20b.pkl
# Pickling array (shape=(3,), dtype=object).
# Memmapping (shape=(985023,), dtype=int64) to new file C:\Users\Oleg\AppData\Local\Temp\joblib_memmapping_folder_23576_9312356208\23576-1560074912544-bcb30020675d4c18adb8d7b97e180c4a.pkl
# Memmapping (shape=(985023,), dtype=int32) to new file C:\Users\Oleg\AppData\Local\Temp\joblib_memmapping_folder_23576_9312356208\23576-1560074912544-376e0bf02d7445838cd1faf84f72d354.pkl
# Memmapping (shape=(985023,), dtype=int64) to new file C:\Users\Oleg\AppData\Local\Temp\joblib_memmapping_folder_23576_9312356208\23576-1560074912544-59d2ee40163a4431b8fcb56ef18c3e13.pkl
# Memmapping (shape=(689516,), dtype=int32) to new file C:\Users\Oleg\AppData\Local\Temp\joblib_memmapping_folder_23576_9312356208\23576-1560074912544-601f8f1702ac4996ab5aead174add22f.pkl
# Memmapping (shape=(295507,), dtype=int32) to new file C:\Users\Oleg\AppData\Local\Temp\joblib_memmapping_folder_23576_9312356208\23576-1560074912544-a94e3235d6a74cf2ac198ccd9d39fea8.pkl
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.4s
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\externals\loky\process_executor.py", line 418, in _process_worker
#     r = call_item()
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\externals\loky\process_executor.py", line 272, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\_parallel_backends.py", line 567, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\parallel.py", line 225, in __call__
#     for func, args, kwargs in self.items]
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\parallel.py", line 225, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\Oleg\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_validation.py", line 544, in _fit_and_score
#     test_scores = _score(estimator, X_test, y_test, scorer)
#   File "C:\Users\Oleg\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_validation.py", line 591, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Oleg\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     *args, **kwargs)
#   File "C:\Users\Oleg\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\_scorer.py", line 260, in _score
#     return self._sign * self._score_func(y, y_pred, **self._kwargs)
#   File "C:\Users\Oleg\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\_ranking.py", line 383, in roc_auc_score
#     multi_class, average, sample_weight)
#   File "C:\Users\Oleg\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\_ranking.py", line 477, in _multiclass_roc_auc_score
#     "Number of classes in y_true not equal to the number of "
# ValueError: Number of classes in y_true not equal to the number of columns in 'y_score'
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-20ee8138e8f7> in <module>
#       1 scores = cross_validate(BernoulliNB(), X_train, y_train, cv=cv, n_jobs=-1,
# ----> 2                         scoring=scoring, verbose=100)
#
# ~\AppData\Roaming\Python\Python36\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     234             return_times=True, return_estimator=return_estimator,
#     235             error_score=error_score)
# --> 236         for train, test in cv.split(X, y, groups))
#     237
#     238     zipped_scores = list(zip(*scores))
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433             else:
#     434                 raise TimeoutError()
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ValueError: Number of classes in y_true not equal to the number of columns in 'y_score'

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RandomForestClassifier().fit(voa_data[:100], target[:100])
# Out:
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-93764fae8958> in <module>
# ----> 1 RandomForestClassifier().fit(voa_data[:100], target[:100])
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     247
#     248         # Validate or convert input data
# --> 249         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     250         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     251         if sample_weight is not None:
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# ValueError: could not convert string to float: 'in'

# %% [markdown]
# ### Gaussian

# %%
import sklearn
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'brier_score_loss',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'max_error',
#  'mutual_info_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'v_measure_score']

# %% [markdown]
# ## CRF

# %%
scoring = ['roc_auc']
cv = ShuffleSplit(n_splits=1, test_size=0.3, random_state=42)

# %%
crf=CRF(algorithm='lbfgs',
         c1=0.1,
         c2=0.1,
         max_iterations=100,
         all_possible_transitions=False)

# %%
crf.fit()

# %%
# scores = cross_validate(crf, X_train, y_train, cv=cv, n_jobs=-1, 
#                          scoring=scoring, verbose=100)
scores = cross_validate(crf, X_train[:100], y_train[:100], cv=cv, n_jobs=-1, 
                         scoring=scoring, verbose=100)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Pickling array (shape=(70,), dtype=int32).
# Pickling array (shape=(30,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    4.2s
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\externals\loky\process_executor.py", line 418, in _process_worker
#     r = call_item()
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\externals\loky\process_executor.py", line 272, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\_parallel_backends.py", line 567, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\parallel.py", line 225, in __call__
#     for func, args, kwargs in self.items]
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\parallel.py", line 225, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\model_selection\_validation.py", line 556, in _fit_and_score
#     test_scores = _score(estimator, X_test, y_test, scorer, is_multimetric)
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\model_selection\_validation.py", line 599, in _score
#     return _multimetric_score(estimator, X_test, y_test, scorer)
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\model_selection\_validation.py", line 629, in _multimetric_score
#     score = scorer(estimator, X_test, y_test)
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\metrics\scorer.py", line 173, in __call__
#     y_type = type_of_target(y)
#   File "D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\utils\multiclass.py", line 260, in type_of_target
#     raise ValueError('You appear to be using a legacy multi-label data'
# ValueError: You appear to be using a legacy multi-label data representation. Sequence of sequences are no longer supported; use a binary array or sparse matrix instead - the MultiLabelBinarizer transformer can convert to this format.
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b6e467631103> in <module>
#       2 #                          scoring=scoring, verbose=100)
#       3 scores = cross_validate(crf, X_train[:100], y_train[:100], cv=cv, n_jobs=-1,
# ----> 4                          scoring=scoring, verbose=100)
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     230             return_times=True, return_estimator=return_estimator,
#     231             error_score=error_score)
# --> 232         for train, test in cv.split(X, y, groups))
#     233
#     234     zipped_scores = list(zip(*scores))
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433             else:
#     434                 raise TimeoutError()
#
# D:\Programs\IDE_and_for_programming\Anaconda\envs\tf-gpu\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ValueError: You appear to be using a legacy multi-label data representation. Sequence of sequences are no longer supported; use a binary array or sparse matrix instead - the MultiLabelBinarizer transformer can convert to this format.

# %%
scores
# Out:
# array([0.97032539, 0.97388456, 0.97253039, 0.97323582, 0.97233593])
