# %% [markdown]
# # Advanced NLP HW0 Reference
#
# Build a text generator based on n-gram language model and neural language model.
#
#     Find a corpus (e.g. http://www.lib.ru/SHAKESPEARE/hamlet2.txt), but you are free to use anything else of your interest
#     Preprocess it if necessary (we suggest using nltk for that)
#     Build an n-gram model
#     Try out different values of n, calculate perplexity on a held-out set
#     Build a simple neural network model for text generation (start from a feed-forward net for example). We suggest using tensorflow + keras for this task
#
# Criteria:
#
#     Data is split into train / validation / test, motivation for the split method is given
#     N-gram model is implemented
#     Neural network for text generation is implemented
#     Perplexity is calculated for both models
#     Examples of texts generated with different models are present and compared

# %%
import requests
import re
import string
from sklearn.model_selection import train_test_split
from collections import defaultdict
from numpy.random import choice
import numpy as np
from collections import Counter
from sklearn.model_selection import ParameterGrid
import pandas as pd

# %%
from tensorflow.keras.layers import Dense, Input, Embedding, Flatten, CuDNNLSTM
from tensorflow.keras import Model
from tensorflow.keras.callbacks import Callback

# %% [markdown]
# ## Data preprocessing

# %%
corpus_url = 'http://lib.ru/POEZIQ/DANTE/comedy.txt'

# %%
response = requests.get(corpus_url)
raw_corpus = response.text

raw_corpus[:25000]
# Out:
# '<html><head><title>Данте Алигьери. Божественная комедия</title></head><body><pre><div align=right><form action=/POEZIQ/DANTE/comedy.txt><select name=format><OPTION VALUE="_Contents">Содержание<OPTION VALUE="_with-big-pictures.html">Fine HTML<OPTION VALUE="_with-big-pictures.html">Printed version<OPTION VALUE="_Ascii.txt">txt(Word,КПК)<OPTION VALUE="">Lib.ru html</select><input type=submit value=go></form></div><pre>\n<ul><a name=0></a><h2>Данте Алигьери. Божественная комедия</h2></ul>\n\n----------------------------------------------------------------------------\n     Перевод М.Лозинского\n     ББК 84.4 Ит\n         Д 17\n     Издательство "Правда", М.: 1982\n     OCR Бычков М.Н.\n----------------------------------------------------------------------------\n\n     "Божественная Комедия" возникла в тревожные ранние  годы  XIV  века  из\nбурливших напряженной политической борьбой глубин национальной жизни Италии.\nДля будущих  -  близких  и  далеких  -  поколений  она  осталась  величайшим\nпамятником поэтической культуры итальянского народа, воздвигнутым на  рубеже\nдвух исторических эпох  Энгельс  писал:  "Конец  феодального  средневековья,\nначало современной капталистической эры отмечены колоссальной фигурой. Это -\nитальянец Данте, последний поэт средневековья и вместе  с  тем  первый  поэт\nновою времени" {К.Маркс и Ф.Энгельс. Сочинения, т. 22, изд. 2-е, с. 382.}.\n     "Суровый Дант" - так назвал  творца  "Божественной  Комедии"  Пушкин  -\nсовершил свой великий поэтический труд в горькие годы изгнания и странствий,\nна   которые   осудила   его    восторжествовавшая    в    1301    году    в\nбуржуазно-демократической Флоренции партия "черных"  -  сторонников  папы  и\nпредставителей интересов дворянско-буржуазной верхушки  богатой  республики.\nВо Флоренции - этом крупнейшем центре итальянской экономической и культурной\nжизни средневековья - Данте Алигьери родился, вырос и возмужал в  атмосфере,\nраскаленной жаждой богатства и власти, раздираемой политическими страстями и\nволнуемой жестокими  междоусобиями.  Здесь,  в  этом  муравейнике  торговли,\nгороде ремесленников и  знатных  купцов,  банкиров  и  надменных  феодальных\nграндов,   в   городе-государстве,   гордом   своим   достатком   и   давней\nнезависимостью, своими древними цеховыми  правами  и  своей  демократической\nконституцией - "Установлениями правосудия" (1293 г.), рано  образуется  один\nиз крупнейших центров того мощного общественно-культурного движения, которое\nсоставило   идейное   содержание   эпохи,   определяемой    Энгельсом    как\n"...величайший прогрессивный переворот из всех  пережитых  до  того  времени\nчеловечеством.." {К.Маркс и Ф.Энгельс. Сочинения, т. 20, изд. 2-е, с. 346.}.\n     Данте  стоит  на  пороге  Возрождения,  на  пороге  эпохи,  "...которая\nнуждалась в титанах и которая породила титанов  по  силе  мысли,  страсти  и\nхарактеру, по многосторонности и учености" {Там же.}.  Творец  "Божественной\nКомедии" был одним из таких титанов, поэтическое наследие которого  осталось\nв веках величественным вкладом итальянского народа  в  сокровищницу  мировой\nкультуры.\n     Отпрыск старой и благородной флорентийской семьи, член  цеха  врачей  и\nаптекарей,  в  состав  которого  входили   лица   различных   интеллигентных\nпрофессий, Данте Алигьери (1265-1321) выступает в своей жизни  как  типичный\nдля его времени и для развитого городского уклада его  родины  представитель\nвсесторонне  образованной,   деятельной,   крепко   связанной   с   местными\nкультурными традициями и общественными интересами интеллигенции.\n     Юность  Данте  протекает  в  блестящем   литературном   кругу   молодой\nпоэтической  школы  "нового   сладостного   стиля"   (doice   stil   nuovo),\nвозглавляемой его  другом  Гвидо  Кавальканти,  и  в  общении  с  выдающимся\nполитическим деятелем и одним из ранних флорентийских гуманистов -  Брунетто\nЛатини.  Зрелые  годы  автор  "Божественной  Комедии"  проводит  на   службе\nреспублики, участвуя в ее войнах, ...

# %%
def preprocess(text):
    TAG_RE = re.compile(r'<[^>]+>') # removing tags
    corpus = TAG_RE.sub('', text) 
    first_chapter_index = corpus.find("АД") # looking for the start
    corpus = corpus[first_chapter_index:]
    remarks_index = corpus.find('ПРИМЕЧАНИЯ') # looking for the end
    corpus = corpus[:remarks_index]
    chapter_RE = re.compile(r'([А-Я]{2,}){1,3}') # removing chapter names
    corpus = re.sub(chapter_RE, ' ', corpus)  
    corpus = re.sub(r"\d+", "", corpus) # removing numbers 
    conversion_table = str.maketrans({key: '' for key in string.punctuation}) #removing punctuation
    corpus = corpus.translate(conversion_table) 
    corpus = re.sub(r' +', ' ', corpus) # substituting several whitespaces with a single one
    corpus = re.sub(r'(\n[ ]*)+', ' \n', corpus) # substituting patterns like \n \n \n  and \n\n\n with a single \n with leading whitespace
    corpus = corpus.lower() #lowercasing everything
    return corpus.strip() #stripping leading whitespaces

# %%
preprocessed_text = preprocess(raw_corpus)

# %%
preprocessed_text[:100]
# Out:
# 'земную жизнь пройдя до половины \nя очутился в сумрачном лесу \nутратив правый путь во тьме долины \nка'

# %% [markdown]
# #### Train/val/test split
# We will split text by lines.
#
# More than a half of the text will be used as a training set.
#
# The rest will be split between validaition and test.

# %%
line_split = preprocessed_text.split(' \n')
line_split[:10]
# Out:
# ['земную жизнь пройдя до половины',
#  'я очутился в сумрачном лесу',
#  'утратив правый путь во тьме долины',
#  'каков он был о как произнесу',
#  'тот дикий лес дремучий и грозящий',
#  'чей давний ужас в памяти несу',
#  'так горек он что смерть едва ль не слаще',
#  'но благо в нем обретши навсегда',
#  'скажу про все что видел в этой чаще',
#  'не помню сам как я вошел туда']

# %%
train_sentences, test_sentences = train_test_split(line_split, train_size = 0.6, shuffle=False)
val_sentences, test_sentences = train_test_split(test_sentences, train_size = 0.5, shuffle=False)

# %%
train_sentences[:10]
# Out:
# ['земную жизнь пройдя до половины',
#  'я очутился в сумрачном лесу',
#  'утратив правый путь во тьме долины',
#  'каков он был о как произнесу',
#  'тот дикий лес дремучий и грозящий',
#  'чей давний ужас в памяти несу',
#  'так горек он что смерть едва ль не слаще',
#  'но благо в нем обретши навсегда',
#  'скажу про все что видел в этой чаще',
#  'не помню сам как я вошел туда']

# %% [markdown]
# #### Fixing vocabulary
#
# We will fix vocabulary for our models -- we will take 10000 most common tokens from the train sample.

# %%
cnt = Counter()
for line in train_sentences:
  cnt.update(line.split(' ') + ['\n'])

# %%
len(cnt)
# Out:
# 14062

# %%
fixed_vocab = [v[0] for v in cnt.most_common(10000)]

# %%
fixed_vocab[:10]
# Out:
# ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так']

# %% [markdown]
# ## Models
#
# Base class for the model.

# %%
class BaseLM:
    def __init__(self, n, vocab=None):
        """Language model constructor
    n -- n-gram size
    vocab -- optional fixed vocabulary for the model
    """
        self.n = n
        self.vocab = vocab

    def prob(self, word, context=None):
        """This method returns probability of a word with given context: P(w_t | w_{t - 1}...w_{t - n + 1})
    
    For example:
    >>> lm.prob('hello', context=('world',))
    0.99988
    """
        raise NotImplementedError

    def generate_text(self, text_length):
        """This method generates random text of length 
    
    For example
    >>> lm.generate_text(2)
    hello world

    """
        raise NotImplementedError

    def update(self, sequence_of_tokens):
        """This method learns probabiities based on given sequence of tokents
    
    sequence_of_tokens -- iterable of tokens

    For example
    >>> lm.update(['hello', 'world'])
    """
        raise NotImplementedError

    def perplexity(self, sequence_of_tokens):
        """This method returns perplexity for a given sequence of tokens
    
    sequence_of_tokens -- iterable of tokens
    """
        raise NotImplementedError

# %% [markdown]
# ## N-gram model

# %%
class NGramLM(BaseLM):
    def __init__(self,
                 n,
                 vocab=None,
                 smoothing_k=1,
                 unk='<UNK>',
                 left_pad='<s>',
                 right_pad='</s>'):
        """N-Gram model constructor
    n -- ngram size
    vocab -- optionally fixed vocabulary
    smoothing_k -- smoothing parameter
    unk -- substitute symbol for handling unknowns
    left_pad -- left padding symbol
    right_pad -- right padding symbol
    """
        self.smoothing_coef = smoothing_k
        super().__init__(n, vocab)
        self.count_context = defaultdict(lambda: defaultdict(lambda: 0))
        self.model = defaultdict(lambda: defaultdict(lambda: 0))
        self.learn_vocab = self.vocab is None
        self.vocab = vocab if vocab is not None else []
        self.left_pad = left_pad
        self.right_pad = right_pad
        self.unk = unk
        self.vocab = [self.left_pad, self.unk, self.right_pad] + self.vocab

    def update(self, sequence_of_tokens):
        """This method learns probabiities based on given sequence of tokents
    """

        #Padding to handle start tokens
        sequence_of_tokens_local = [self.left_pad] * (self.n - 1) + list(
            sequence_of_tokens) + [self.right_pad]

        #Substitution of unknown symbols
        if not self.learn_vocab:
            sequence_of_tokens_local = [
                s if s in self.vocab else self.unk for s in sequence_of_tokens
            ]

        #Generation of n-grams
        ngrams = zip(*[sequence_of_tokens_local[i:] for i in range(self.n)])

        #Learning vocab if necessary
        for ngram in ngrams:
            if self.learn_vocab:
                for v in ngram:
                    if v not in self.vocab:
                        self.vocab.append(v)

            #Context / word
            context = tuple(ngram[:-1])
            word = ngram[-1]

            #Update counts
            self.count_context[context][word] += 1

        #Setting smoothed probability if context is unknown
        self.model = defaultdict(lambda: 1 / len(self.vocab))

        for context in self.count_context.keys():
            #Denominator of k-smoothed P(w | w_i...w_{i-n+1}) MLE
            denominator = sum(self.count_context[context].values()
                              ) + self.smoothing_coef * len(self.vocab)

            #Setting smoothed probability if token is unknown
            self.model[context] = defaultdict(
                lambda: self.smoothing_coef / denominator)
            for word in self.count_context[context].keys():
                #Smothed probability estimate for known ngrams
                self.model[context][word] = (
                    self.smoothing_coef +
                    self.count_context[context][word]) / denominator

    def prob(self, word, context=None):
        """This method returns probability of a word with given context: P(w_t | w_{t - 1}...w_{t - n + 1})
    """

        #Try to find context
        context_probs = self.model[context]

        #Context is not found and the default probability returned
        if not isinstance(context_probs, defaultdict):
            return context_probs

        #Return probability estimate
        return self.model[context][word]

    def generate_text(self, text_length, sep=' '):
        """This method generates random text of length text_length
    """
        #Creaing starting context
        context = tuple([self.left_pad] * (self.n - 1))

        generated_tokens = []
        for t in range(text_length):
            #Distribution estimate over vocabulary
            distribution_over_vocab = [
                self.prob(v, context) for v in self.vocab
            ]

            #Generation of next token
            next_word = choice(self.vocab,
                               replace=False,
                               size=1,
                               p=np.array(distribution_over_vocab) /
                               sum(distribution_over_vocab))[0]
            generated_tokens.append(next_word)

            #Generation of a new context
            context = tuple(list(context[1:]) + [next_word])

        return sep.join(generated_tokens)

    def perplexity(self, sequence_of_tokens):
        """This method returns perplexity for a given sequence of tokens
    """
        #Padding sequence of tokens
        sequence_of_tokens_local = [self.left_pad] * (self.n - 1) + [
            s if s in self.vocab else self.unk for s in sequence_of_tokens
        ] + [self.right_pad]

        #Generation of n-grams
        ngrams = zip(*[sequence_of_tokens_local[i:] for i in range(self.n)])

        probs = []

        #Probability for each token
        for ngram in ngrams:
            context = tuple(ngram[:-1])
            word = ngram[-1]
            probs.append(np.log2(self.prob(word, context)))

        #Perplexity
        return 2**(-sum(probs) / len(sequence_of_tokens_local))

# %%
def lm_tuning(lm_class, params_dict, train_set, validation_set, verbose=0):
    """Method for tuning language model
    lm_class -- language model class
    params_dict -- dictionary of parameters for the model
    train_set -- sequence of tokens for training 
    validation_set -- sequence of tokens for validation
    verbose -- verbosity parameter 0 -- print nothing, or >0 -- prints scores and parameters
    """
    grid = ParameterGrid(params_dict)
    best_params = None
    best_perplexity = np.Inf
    best_model = None

    for param_set in grid:

    if verbose > 0:
        print(param_set)

    ngram = lm_class(**param_set)
    ngram.update(train_set)
    perp = ngram.perplexity(validation_set)

    if verbose > 0:
        print(perp)
    if np.less(perp, best_perplexity):
        best_params = param_set
        best_perplexity = perp
        best_model = ngram

    if verbose > 0:
    print('Best params: {}\nBest perplexity: {}'.format(best_params, best_perplexity))
    return best_model

# %%
' \n '.join(train_sentences[:5]).split(' ')
# Out:
# ['земную',
#  'жизнь',
#  'пройдя',
#  'до',
#  'половины',
#  '\n',
#  'я',
#  'очутился',
#  'в',
#  'сумрачном',
#  'лесу',
#  '\n',
#  'утратив',
#  'правый',
#  'путь',
#  'во',
#  'тьме',
#  'долины',
#  '\n',
#  'каков',
#  'он',
#  'был',
#  'о',
#  'как',
#  'произнесу',
#  '\n',
#  'тот',
#  'дикий',
#  'лес',
#  'дремучий',
#  'и',
#  'грозящий']

# %%
ngram = lm_tuning(NGramLM,
                  params_dict = {'n': list(range(2,6)),
                                'smoothing_k': [0.001, 0.01, 0.1, 0.5, 1.0],
                                'vocab':[fixed_vocab]},
                  train_set=' \n '.join(train_sentences).split(' '),
                  validation_set=' \n '.join(val_sentences).split(' '),
                  verbose=1)
# Out:
# {'n': 2, 'smoothing_k': 0.001, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'пр ...
# 244.0849954072429
# {'n': 2, 'smoothing_k': 0.01, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'пра ...
# 302.0092480996544
# {'n': 2, 'smoothing_k': 0.1, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'прах ...
# 511.0083358573151
# {'n': 2, 'smoothing_k': 0.5, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'прах ...
# 907.2789061733666
# {'n': 2, 'smoothing_k': 1.0, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'прах ...
# 1215.8559071879688
# {'n': 3, 'smoothing_k': 0.001, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'пр ...
# 1605.8765920144185
# {'n': 3, 'smoothing_k': 0.01, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'пра ...
# 1966.604998074081
# {'n': 3, 'smoothing_k': 0.1, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'прах ...
# 2963.2311829773935
# {'n': 3, 'smoothing_k': 0.5, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'прах ...
# 4292.803869544788
# {'n': 3, 'smoothing_k': 1.0, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'прах ...
# 5021.50088320917
# {'n': 4, 'smoothing_k': 0.001, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'пр ...
# 5196.821563114331
# ...
# 9135.768558029851
# {'n': 5, 'smoothing_k': 0.5, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'прах ...
# 9491.103809051257
# {'n': 5, 'smoothing_k': 1.0, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут', 'путь', 'она', 'во', 'те', 'лишь', 'один', 'дух', 'пока', 'свой', 'без', 'им', 'тех', 'нет', 'еще', 'потом', 'только', 'учитель', 'твой', 'да', 'мной', 'речь', 'вы', 'видел', 'тем', 'взгляд', 'было', 'была', 'со', 'взор', 'есть', 'иль', 'вас', 'меж', 'быть', 'свет', 'начал', 'ли', 'ей', 'ответ', 'или', 'них', 'ответил', 'мог', 'нем', 'этой', 'тогда', 'сквозь', 'себя', 'вновь', 'этих', 'такой', 'стал', 'теперь', 'хоть', 'пред', 'эти', 'может', 'нами', 'себе', 'ней', 'были', 'вдруг', 'затем', 'глаза', 'шел', 'пусть', 'туда', 'вам', 'слова', 'б', 'скажи', 'едва', 'час', 'той', 'том', 'будет', 'идет', 'столь', 'круг', 'душа', 'словно', 'любовь', 'среди', 'того', 'тени', 'наш', 'грудь', 'ко', 'этом', 'пути', 'вдоль', 'каждый', 'эта', 'вперед', 'шли', 'перед', 'мир', 'средь', 'другой', 'моя', 'промолвил', 'солнце', 'тело', 'та', 'тень', 'моих', 'всем', 'чуть', 'сын', 'весь', 'земле', 'лицо', 'миг', 'даже', 'больше', 'чей', 'опять', 'вожатый', 'снова', 'края', 'души', 'идти', 'два', 'надо', 'моим', 'видишь', 'кругом', 'друг', 'зачем', 'взгляни', 'людей', 'вниз', 'время', 'дальше', 'кого', 'него', 'про', 'сердце', 'вверх', 'мире', 'тобой', 'моей', 'другим', 'сейчас', 'глаз', 'одна', 'нему', 'сюда', 'любви', 'три', 'вижу', 'первый', 'род', 'народ', 'вергилий', 'должен', 'теней', 'речи', 'отец', 'хотя', 'ль', 'которым', 'при', 'шаг', 'вслед', 'вослед', 'чья', 'новый', 'прежде', 'много', 'люди', 'рядом', 'этим', 'срок', 'пор', 'эту', 'страх', 'день', 'разум', 'увидел', 'спросил', 'мои', 'вид', 'когдато', 'ваш', 'которые', 'ведь', 'самый', 'воздух', 'душ', 'будь', 'своих', 'света', 'цвет', 'которых', 'мук', 'которая', 'облик', 'куда', 'грех', 'кровь', 'отвечал', 'увидеть', 'таков', 'слово', 'вокруг', 'знай', 'своей', 'склон', 'тому', 'дни', 'знать', 'руки', 'образ', 'спутник', 'внизу', 'казалось', 'человек', 'земли', 'которой', 'выше', 'ждет', 'нельзя', 'голос', 'рук', 'горе', 'край', 'других', 'толпа', 'мое', 'готов', 'жизнь', 'назад', 'дал', 'будто', 'лик', 'смотри', 'ныне', 'другом', 'твоей', 'ними', 'таким', 'жизни', 'скал', 'всю', 'лицом', 'головой', 'твои', 'звук', 'другого', 'вполне', 'тотчас', 'настолько', 'увидал', 'вся', 'взглядом', 'пора', 'откуда', 'труд', 'иди', 'глубине', 'сначала', 'кем', 'знал', 'крик', 'какой', 'зная', 'между', 'говорил', 'встретил', 'двух', 'след', 'раньше', 'лица', 'всего', 'вблизи', 'слышал', 'желанье', 'иной', 'имя', 'язык', 'навстречу', 'высот', 'зверь', 'огня', 'город', 'твоя', 'рассказ', 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил', 'слезах', 'прах ...
# 9623.589303241393
# Best params: {'n': 2, 'smoothing_k': 0.001, 'vocab': ['\n', 'и', 'в', 'я', 'не', 'как', 'он', 'что', 'на', 'так', 'к', 'с', 'ты', '', 'мне', 'был', 'но', 'кто', 'а', 'мой', 'где', 'их', 'когда', 'мы', 'о', 'от', 'бы', 'там', 'все', 'тот', 'здесь', 'его', 'из', 'за', 'сказал', 'чтоб', 'меня', 'то', 'по', 'у', 'чем', 'нам', 'нас', 'если', 'вот', 'это', 'же', 'этот', 'вождь', 'уже', 'ни', 'ему', 'до', 'для', 'они', 'над', 'всех', 'тебя', 'ним', 'который', 'раз', 'тебе', 'молвил', 'чтобы', 'ее', 'под', 'сам', 'тут
 'подняться', 'быстрей', 'рад', 'сила', 'мною', 'ноги', 'ног', 'огонь', 'некий', 'своим', 'сколько', 'великий', 'рукой', 'лет', 'меньше', 'всей', 'вод', 'две', 'сказав', 'небес', 'стоит', 'уж', 'оно', 'камень', 'жив', 'внутри', 'смерть', 'чье', 'такая', 'свою', 'царь', 'своем', 'узнать', 'тьму', 'хочешь', 'слезы', 'славы', 'небо', 'суд', 'понял', 'чьи', 'бога', 'дорога', 'ближе', 'тела', 'всегда', 'хотел', 'чему', 'милый', 'чего', 'напрасно', 'друга', 'дает', 'дно', 'ступени', 'знаю', 'добрый', 'сил', 'место', 'могли', 'брат', 'скажу', 'сонм', 'изза', 'поэт', 'честь', 'дорогу', 'кому', 'зла', 'душу', 'путем', 'мысль', 'нужно', 'должно', 'сказать', 'смело', 'одним', 'руку', 'сени', 'боль', 'гнев', 'слов', 'свои', 'вкруг', 'очей', 'плоть', 'уст', 'вместе', 'какая', 'ждал', 'двое', 'нашей', 'вал', 'бежит', 'руками', 'дня', 'очи', 'немного', 'почему', 'гвидо', 'твоих', 'внимая', 'совсем', 'крови', 'слишком', 'землю', 'помог', 'говорит', 'одного', 'воля', 'ночь', 'наверх', 'стало', 'силы', 'сон', 'берег', 'жил',  ...
# Best perplexity: 244.0849954072429

# %%
ngram.perplexity(' \n '.join(test_sentences).split(' '))
# Out:
# 235.64339119774746

# %%
print(ngram.generate_text(1000))
# Out:
# вредоносной смысла комунибудь дремучий рассталась капаней в желчь родимым гребнем перевидал выстрел груда скал обагривших кровью утомленный опустился преклонись во лес разгородили мертвыми падай трепещущее швырять скорбный склеп теченью давившей достойные мненье верного вождя уста голени ли кто размышлял до тронь презренье головными впереди неутомимо томный мечет их всех пособя найди борьбе могло поясом нашем истину полмили растения бездонный шьют будто вера уроки убитый
#  пылью рубежа окраска житья смертью осквернено плечи только мне монтаперти острые лежавших это высоте втайне казнишь пятки горя
#  иссох светит ведущей души два брату если судит войны гнусный огибая арахна пройти исступленный молится кумиру
#  коз объята вековечной нежданно грянул сомнением цепь докончив вздохи куколь тьму сильней огни
#  я речь вести гадины меняют язвит своевольно достойные величавой
#  распаленный призывать сужу пред именем твоим носящий хрипа скопища пей ручьи края властелин привстал умерщвленной измлада взирает изваянный слуху смертного наставленье гибнущих громоздятся слепая пловец горнила дверь широк и <UNK> мраке всхлипнул небо словно злая
#  и песнь искусств связь взахлест которого шли
#  кто это снилось жар рухнув записи умолк казалось будто огнивом мягчит владеет гонимой книгах сокольник спросят владыки напротив кенхр просят лишь навсегда сильвестра дрему сын ступай один другого
#  круглом рву оплетены предавшего выкрикивали видя медвежатам особый отяготели облаве близ него обуза наша клока неуступчивы прибою соседей пресек теле пенелопы герардо знаменитый
#  чтоб быстрине церкви кака услышать пенелопы с главою чернотой потайных мотовство земного лучшую средь ледяных нептун росло взбежав струятся глубоком нагим громада локоть хмурой леща соскабливает точности снова да помоги костей пояс обвитый стройными стенами небесной врозь подплыв каков стоп сонма птице проклятом маркиза осуждены цель миль стеклом могучих лоном двадцатой услышав этой первой малюток
#  семья христиан полагает взрыхлил ближе топкий верного нейдет тяжестью одиноких разлившись оскорблен скрывавшей сражаешь пяткой сколькими господне звал <UNK> улыбнулся обманувшую капрара дрожа приблизилась сама грохоча беседовали воззваньем раздается эфиопа иуда опушки строившие раздробил младенца направлял знак дают дельфины тяжелей проникал впредь склоне фламандцев ворота пустыней свисающий мостового дар <UNK>
#  тот кто эти люди впускает вцепившегося прежние кривоглазый сходил хвоста эта слава первою несчастный предавался судьбой следовать большая своей основались фив
#  чтоб кровь которой зверя нет пустынна сращенья надгорной умерла чтоб зверь взойти
#  поэту лжец синон поселян несходной всяческою выю избыток присяду ночным зарок рассказал исполнившие разум огнепалящий тишине
#  вещуном повода вернуть корона продолжали обеими хоть рыдал дьяволы кентавр казнимого тише отучен
#  <UNK> <UNK> мздоимцев скосы следу милых кудри права свивая раздирало довольно скачет объята
#  огне гвиттон господня решали заполняет гибнут чреват хранящей твоя и мне и доброго ж у нас безвестной
#  чтоб принесшем ступеней у казною скрыв младенцев седого уподоблялась нравам
#  здесь жди стихами передает жрица
#  земная светлеет разлаялся кой сумрачную правдивей забирай глядит назад луни просвет карают вздулись прям истинно утратив чтец проглянет нечестивый серебро литое
#  которого утруждали сосед обманывает таил вопил слышно вор меньший грех тристан ненасытно севилья утесе головными ретив большое раскрытый обомкнуть сильный несветел бежали встретившись ворвался служат морду утомленный рассержен престол для <UNK>
#  луг ужасе обиде прато обманувшую скорбя змеи отраду поражен цирцеей отцу шевелит камень намечал восходят вошли левей <UNK> род греки былым ярмом сквозь полусфер и рвом в ценой
#  страшась вместо катится вниз держали отпустил

# %% [markdown]
# ## Neural language model

# %%
class PerplexityEarlyStopping(Callback):
  """Callback for early stopping based on perplexity on the validation set
  """
  def __init__(self, validation_data):
    super().__init__()
    self.contexts, self.targets = validation_data
    self.best = np.Inf
  
  def on_epoch_end(self, epoch, logs=None):
    pred = self.model.predict(self.contexts)
    probs = [np.log2(pred[i, target[0]]) for i, target in enumerate(self.targets)]
    perp = 2**(-sum(probs) / self.targets.shape[0])
    print('- perplexity: {}'.format(perp))
    if np.less(perp, self.best):
      self.best = perp
    else:
      self.model.stop_training = True
      print('Early stopping due to higher perplexity')

# %%
class NeuralLM(BaseLM):
    def __init__(self,
                 n,
                 vocab=None,
                 unk='<UNK>',
                 left_pad='<s>',
                 right_pad='</s>'):
        """Neural language model constructor
    n -- ngram size
    vocab -- optionally fixed vocabulary
    unk -- substitute symbol for handling unknowns
    left_pad -- left padding symbol
    right_pad -- right padding symbol
    """

        super().__init__(n, vocab)
        self.learn_vocab = vocab is None
        self.vocab = vocab if vocab is not None else []
        self.left_pad = left_pad
        self.right_pad = right_pad
        self.unk = unk
        self.vocab = [self.left_pad, self.unk, self.right_pad] + self.vocab
        self.word_idx = {v: i for i, v in enumerate(self.vocab)}
        self.model = None

    def build_model(self):
        """Method for building neural net
    """
        inp = Input(shape=self.n - 1, name='sequence_input')
        emb = Embedding(input_dim=len(self.vocab),
                        output_dim=50,
                        input_length=self.n - 1)(inp)
        flat = Flatten()(emb)
        dense = Dense(len(self.vocab), activation='softmax')(flat)
        model = Model(inputs=[inp], outputs=[dense])
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
        return model

    def update(self, sequence_of_tokens, validation_sequence=None):
        """This method learns probabiities based on given sequence of tokents
    """

        #Padding given sequence
        sequence_of_tokens_local = [self.left_pad] * (self.n - 1) + list(
            sequence_of_tokens) + [self.right_pad]

        #Substituting unknown tokens
        if not self.learn_vocab:
            sequence_of_tokens_local = [
                s if s in self.vocab else self.unk
                for s in sequence_of_tokens_local
            ]

        #Generation of n-grams
        ngrams = zip(*[sequence_of_tokens_local[i:] for i in range(self.n)])

        contexts = []
        targets = []

        #Learing vocab if necessary
        #Forming train matrix and lebels vector
        for ngram in ngrams:
            if self.learn_vocab:
                for v in ngram:
                    if v not in self.vocab:
                        self.word_idx[v] = len(self.vocab)
                        self.vocab.append(v)

            context = [self.word_idx[v] for v in ngram[:-1]]
            contexts.append(context)

            target = [self.word_idx[ngram[-1]]]
            targets.append(target)

        self.model = self.build_model()

        contexts_val = []
        targets_val = []

        #If validation data is given -- generate matrix and targets vector
        if validation_sequence is not None:
            validation_sequence_local = [self.left_pad] * (self.n - 1) + [
                s if s in self.vocab else self.unk for s in validation_sequence
            ] + [self.right_pad]
            ngrams_val = zip(
                *[validation_sequence_local[i:] for i in range(self.n)])

            for ngram in ngrams_val:
                context = [self.word_idx[v] for v in ngram[:-1]]
                contexts_val.append(context)
                target = [self.word_idx[ngram[-1]]]
                targets_val.append(target)

        validation_data = [np.array(contexts_val),
                           np.array(targets_val)
                           ] if validation_sequence is not None else None

        #Early stopping based on perplexity on validation set
        callbacks = None if validation_data is None else [
            PerplexityEarlyStopping(validation_data=validation_data)
        ]

        self.model.fit(x=np.array(contexts),
                       y=np.array(targets),
                       batch_size=256,
                       epochs=100,
                       validation_data=validation_data,
                       callbacks=callbacks)

    def prob(self, word, context=None):
        """This method returns probability of a word with given context: P(w_t | w_{t - 1}...w_{t - n + 1})
    """

        input_seq = np.array([[self.word_idx[v] for v in context]])
        pred = self.model.predict(input_seq)
        return pred[0, self.word_idx[word]]

    def generate_text(self, text_length, sep=' '):
        """This method generates random text of length text_length
    """
        context = tuple([self.left_pad] * (self.n - 1))

        generated_tokens = []

        for t in range(text_length):
            #Estimate of the distribution over vocabulary
            input_seq = np.array([[self.word_idx[v] for v in context]])
            pred = self.model.predict(input_seq)
            distribution_over_vocab = [
                pred[0, self.word_idx[v]] for v in self.vocab
            ]

            #Generation of the next token
            next_word = choice(self.vocab,
                               replace=False,
                               size=1,
                               p=np.array(distribution_over_vocab) /
                               sum(distribution_over_vocab))[0]
            generated_tokens.append(next_word)

            #Updating context
            context = tuple(list(context[1:]) + [next_word])
        return sep.join(generated_tokens)

    def perplexity(self, sequence_of_tokens):
        """This method returns perplexity for a given sequence of tokens
    """

        #Padding
        sequence_of_tokens_local = [self.left_pad] * (self.n - 1) + [
            s if s in self.vocab else self.unk for s in sequence_of_tokens
        ] + [self.right_pad]

        #Generation of n-grams
        ngrams = zip(*[sequence_of_tokens_local[i:] for i in range(self.n)])

        probs = []

        #Probability calculation
        for ngram in ngrams:
            context = tuple(ngram[:-1])
            word = ngram[-1]
            probs.append(np.log2(self.prob(word, context)))

        return 2**(-sum(probs) / len(sequence_of_tokens_local))

# %%
nnlm = NeuralLM(n = 4, vocab=fixed_vocab)

# %%
nnlm.update(' \n '.join(train_sentences).split(' '), validation_sequence=' \n '.join(val_sentences).split(' '))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 57731 samples, validate on 18932 samples
# Epoch 1/100
# 57600/57731 [============================>.] - ETA: 0s - loss: 8.0818 - acc: 0.1014- perplexity: 267.8390942564543
# 57731/57731 [==============================] - 4s 73us/sample - loss: 8.0795 - acc: 0.1015 - val_loss: 5.5904 - val_acc: 0.1842
# Epoch 2/100
# 56832/57731 [============================>.] - ETA: 0s - loss: 6.5921 - acc: 0.1744- perplexity: 206.51784934433618
# 57731/57731 [==============================] - 4s 64us/sample - loss: 6.5936 - acc: 0.1742 - val_loss: 5.3304 - val_acc: 0.2175
# Epoch 3/100
# 56832/57731 [============================>.] - ETA: 0s - loss: 6.3009 - acc: 0.1866- perplexity: 181.87529010350912
# 57731/57731 [==============================] - 4s 64us/sample - loss: 6.2982 - acc: 0.1869 - val_loss: 5.2033 - val_acc: 0.2498
# Epoch 4/100
# 56832/57731 [============================>.] - ETA: 0s - loss: 6.0816 - acc: 0.1954- perplexity: 169.92479313634183
# 57731/57731 [==============================] - 4s 65us/sample - loss: 6.0830 - acc: 0.1954 - val_loss: 5.1354 - val_acc: 0.2604
# Epoch 5/100
# 56832/57731 [============================>.] - ETA: 0s - loss: 5.8770 - acc: 0.2023- perplexity: 159.88292101307349
# 57731/57731 [==============================] - 4s 63us/sample - loss: 5.8764 - acc: 0.2021 - val_loss: 5.0744 - val_acc: 0.2732
# Epoch 6/100
# 56832/57731 [============================>.] - ETA: 0s - loss: 5.6602 - acc: 0.2075- perplexity: 155.54603364308807
# 57731/57731 [==============================] - 4s 64us/sample - loss: 5.6604 - acc: 0.2077 - val_loss: 5.0469 - val_acc: 0.2764
# Epoch 7/100
# 57088/57731 [============================>.] - ETA: 0s - loss: 5.4396 - acc: 0.2127- perplexity: 152.9072795812289
# 57731/57731 [==============================] - 4s 63us/sample - loss: 5.4388 - acc: 0.2128 - val_loss: 5.0298 - val_acc: 0.2822
# Epoch 8/100
# 57088/57731 [============================>.] - ETA: 0s - loss: 5.2147 - acc: 0.2171- perplexity: 154.51045396254386
# Early stopping due to higher perplexity
# 57731/57731 [==============================] - 4s 63us/sample - loss: 5.2153 - acc: 0.2171 - val_loss: 5.0403 - val_acc: 0.2827

# %%
nnlm.perplexity(' \n '.join(test_sentences).split(' '))
# Out:
# 151.68401143406666

# %%
print(nnlm.generate_text(1000))
# Out:
# племен
#  я так как бы мы из <UNK> и желанье
#  где огней раз знай напротив вскричал <UNK> увидеть бы чреда
#  ты то под мной напрасно
#  такой фьоренца башни пел так скрыться понемногу
#  и отдыха шестым были судя крикнул больше была вожатый
#  идем лает вонзился был как до <UNK> снова
#  что нежной даже внемлют ее облечен стремила
#  он что мы брата их взойдешь ему кому
#  уже с ним не сердится лета
#  скорбный прах всех попустому
#  звезде донимает ту отпрыск дом
#  когда нам пора ран я про грудь светлый впадин не нас свой <UNK>
#  зло <UNK> от сюда иль движенья
#  сказал все вновь начал с ним тело те за палицей странный посад осталась защита чутьчуть
#  он в твой мире столь сородичем слова р
#  из подо не отяжелел за ты бы <UNK> ни шел и <UNK> и фивян
#  рассеяв птицей светлым промолвить властелином затем
#  но стигийское иное души манит в твоем раз не исчезла плоти <UNK> но враги que речь правей древний втайне врат лучей горб владыкам милость озаренной
#  который полно </s> к разве нелюдимый
#  сперва в утробе <UNK> <UNK> <UNK>
#  от мне ты меня огнепалящий сужденный
#  ты головы как же я встретил там мой вождь где безлюдный
#  лицезренья этих сторон
#  почет обернулся страны
#  ваш двое над плиты не вернувшись ни и света
#  вместе <UNK> <UNK>
#  но если в нем вопроса не избранный
#  в ж же <UNK> же там <UNK> рук спокоен
#  дай смело век кровь
#  здесь на сердце <UNK> <UNK>
#  свою стихах с друга он камнями почет бедствии слова отсек
#  читатель высотах <UNK>
#  так на казною
#  та мертвый любил краю учил крепкие ничто мог сени
#  а эти так вперед
#  полон что сказал взгляд
#  дол лег грешить беду
#  он стал и и здесь тот что в маремме чаще
#  но кто б взгляд на словам
#  его я один он не так мной гонит напрасно
#  хулой шагали господня восходящих сказать крыла
#  скажи бонифаций <UNK> <UNK> ход
#  чем я там к мне срам и челнок пар <UNK>
#  тебя сэр над покрывала вторя пестрого каменья равно где каррарец скикки свет вод
#  и нас за ним из покинул захочешь сольданьер
#  но к нам начатую подвинулись вальдикьяны мучит
#  ответил не дождь в <UNK> уст <UNK>

# %% [markdown]
# ## Models comparison
#
# Let's create several models with different context size.
#
# We will compare perplexities and will look at generated texts.

# %%
df_comp_model = pd.DataFrame([], columns=['model_type', 'n', 'train_perplexity', 'val_perplexity','test_perplexity', 'generated text'])

# %% [markdown]
# Running n-gram models for n in [2, 10] and smoothing parameter chosen on validation set.

# %%
for i in range(2, 11):
  model_type = 'ngram_lm'
  n = i
  ngram = lm_tuning(NGramLM,
                    params_dict = {'n': [i],
                                   'smoothing_k': [0.001, 0.01, 0.1, 0.5, 1.0],
                                   'vocab':[fixed_vocab]},
                    train_set=' \n '.join(train_sentences).split(' '),
                    validation_set=' \n '.join(val_sentences).split(' '),
                    verbose=0)
  
  train_perplexity=ngram.perplexity(' \n '.join(train_sentences).split(' '))
  val_perplexity=ngram.perplexity(' \n '.join(val_sentences).split(' '))
  test_perplexity=ngram.perplexity(' \n '.join(test_sentences).split(' '))
  generated_text = ngram.generate_text(1000)
  df_comp_model = df_comp_model.append(pd.DataFrame([[model_type, n, train_perplexity, val_perplexity, test_perplexity, generated_text]],
                                    columns=['model_type', 'n', 'train_perplexity', 'val_perplexity','test_perplexity', 'generated text']),ignore_index=True)

# %% [markdown]
# Running Neural Language models for n in [2, 10] and early stopping by perplexity on validation set.

# %%
for i in range(2, 11):
  model_type = 'neural_lm'
  n = i
  nnlm = NeuralLM(n = n, vocab=fixed_vocab)
  nnlm.update(' \n '.join(train_sentences).split(' '),
              validation_sequence=' \n '.join(val_sentences).split(' '))
  
  train_perplexity=nnlm.perplexity(' \n '.join(train_sentences).split(' '))
  val_perplexity=nnlm.perplexity(' \n '.join(val_sentences).split(' '))
  test_perplexity=nnlm.perplexity(' \n '.join(test_sentences).split(' '))
  generated_text = nnlm.generate_text(1000)

  df_comp_model = df_comp_model.append(pd.DataFrame([[model_type, n, train_perplexity, val_perplexity, test_perplexity, generated_text]],
                                    columns=['model_type', 'n', 'train_perplexity', 'val_perplexity','test_perplexity', 'generated text']),ignore_index=True)
# Out:
# Train on 57731 samples, validate on 18932 samples
# Epoch 1/100
#
100
# 57600/57731 [============================>.] - ETA: 0s - loss: 5.8584 - acc: 0.2072- perplexity: 155.29064563943973
# 57731/57731 [==============================] - 5s 81us/sample - loss: 5.8585 - acc: 0.2071 - val_loss: 5.0453 - val_acc: 0.2962
# Epoch 4/100
# 57600/57731 [============================>.] - ETA: 0s - loss: 5.4919 - acc: 0.2154- perplexity: 153.16911483400023
# 57731/57731 [==============================] - 5s 81us/sample - loss: 5.4915 - acc: 0.2154 - val_loss: 5.0315 - val_acc: 0.3007
# Epoch 5/100
# 57344/57731 [============================>.] - ETA: 0s - loss: 4.9863 - acc: 0.2236- perplexity: 156.51361387665494
# Early stopping due to higher perplexity
# 57731/57731 [==============================] - 5s 80us/sample - loss: 4.9855 - acc: 0.2237 - val_loss: 5.0531 - val_acc: 0.3036
# Train on 57731 samples, validate on 18932 samples
# Epoch 1/100
# 56832/57731 [============================>.] - ETA: 0s - loss: 7.4889 - acc: 0.1560- perplexity: 186.30834352651993
# 57731/57731 [==============================] - 5s 91us/sample - loss: 7.4738 - acc: 0.1563 - val_loss: 5.2274 - val_acc: 0.2204
# Epoch 2/100
# 56832/57731 [============================>.] - ETA: 0s - loss: 6.1427 - acc: 0.1952- perplexity: 157.71107293694988
# 57731/57731 [==============================] - 5s 91us/sample - loss: 6.1403 - acc: 0.1956 - val_loss: 5.0608 - val_acc: 0.2909
# Epoch 3/100
# 56832/57731 [============================>.] - ETA: 0s - loss: 5.7968 - acc: 0.2119- perplexity: 151.4863661203748
# 57731/57731 [==============================] - 5s 83us/sample - loss: 5.7961 - acc: 0.2120 - val_loss: 5.0205 - val_acc: 0.3000
# Epoch 4/100
# 56832/57731 [============================>.] - ETA: 0s - loss: 5.3834 - acc: 0.2198- perplexity: 151.23161432698
# 57731/57731 [==============================] - 5s 83us/sample - loss: 5.3818 - acc: 0.2197 - val_loss: 5.0188 - val_acc: 0.3048
# Epoch 5/100
# 57600/57731 [============================>.] - ETA: 0s - loss: 4.7948 - acc: 0.2287- perplexity: 157.13855408097615
# Early stopping due to higher perplexity
# 57731/57731 [==============================] - 5s 83us/sample - loss: 4.7939 - acc: 0.2288 - val_loss: 5.0571 - val_acc: 0.3047

# %%
df_comp_model.sort_values('test_perplexity')
# Out:
#    model_type  ...                                     generated text
# 13  neural_lm  ...  прахе милый сердцах он который слушать скаты в...
# 12  neural_lm  ...  упала \n когда взор по и взоры \n в душе связа...
# 14  neural_lm  ...  зренье судив б пытливо братьям \n мирской поск...
# 11  neural_lm  ...  током пришло которые нас медлил мошной не спол...
# 16  neural_lm  ...  имя мне над а я вновь латинской светлеет видиш...
# 15  neural_lm  ...  глазами челе \n речь сковал если но воскликнул...
# 17  neural_lm  ...  вершина одни которым \n на он и мне <UNK> \n и...
# 10  neural_lm  ...  тьме входящим ногам \n как его горит \n <UNK> ...
# 9   neural_lm  ...  заметив суставы пятым \n они предстали растил ...
# 0    ngram_lm  ...  пиза ускорим звуком однажды стычкам разговору ...
# 1    ngram_lm  ...  толпы свернутый расчел суша глубину подъемля д...
# 2    ngram_lm  ...  через мудрый видно обрушенный качча чтил сгреб...
# 3    ngram_lm  ...  просьбы трубы деревьям безгласно созвучьях мер...
# 4    ngram_lm  ...  клыки покров стихах шага больной межу гласивше...
# 5    ngram_lm  ...  изведать рощи жаждал подлинно обломаешь рать л...
# 6    ngram_lm  ...  уберечь следил ветром владеет чугуном сходом с...
# 7    ngram_lm  ...  милей закрыт замковой шестого убор стоянки сби...
# 8    ngram_lm  ...  вероною серебро голуби вскричав влипших держащ...
#
# [18 rows x 6 columns]

# %% [markdown]
# The table above shows that neural language model generally outperforms n-gram model in terms of perplexity.
#
# Let us take a look at the generated texts.

# %% [markdown]
# ### Text generated by the model with the lowest test perplexity

# %%
print(df_comp_model.sort_values('test_perplexity')['generated text'].values[0])
# Out:
# прахе милый сердцах он который слушать скаты вышине
#  поведай чьей беседы платками владыкам
#  так здесь промолвил в голове камилла
#  раз была кого медля <UNK>
#  так то что что немало ров
#  кто лишь он и веры добру чести фуччи
#  тут явно дыме нему как пестрого куда
#  я забияка ногой сейчас мешок
#  взмывал сам меру распознать вперед изогнул на стран
#  от сограждан он и я со в лад
#  чем он такой не и была
#  взглянув не ними когда скала
#  и собой на обличье виду
#  мне он <UNK> как долгих тело
#  так ты он и обуянный
#  найти моей земляк встал
#  калечит чудо я отца толпы напротив зияло
#  чему все что врагом его неизреченной
#  к нам и ступай им
#  что мой вождь почет межи
#  взгляни ваше таким кто жизнь повторит
#  но я бегущий взял светил же смотришь которым
#  я сказал пошел мой к другом
#  но другая <UNK> <UNK> красоту
#  когда эней сестра беатриче божий
#  тебе в <UNK> примиренья
#  чем начал нессу смыкаются мало
#  потом огней вы крылья нет
#  его некий и дальше положен
#  чтобы тот кто на так от <UNK>
#  затем что мышки и красив бы стоя сойдя идет ты освирепело
#  ступай ахиллов вергилий сильвиев он
#  как дух это прозвучало
#  без и может он <UNK>
#  я выше я в лесу <UNK>
#  других я в услышав слову
#  о значенье ни завистью нас
#  их нашей и водопад за крови
#  я сестра так из беспокойся
#  иль плачет здесь присных
#  когда мой корысти благ же <UNK> <UNK>
#  ответь видел как не уповая твой
#  добра начал заманит у подмогу
#  мои впустую средь жена
#  что что он даже от
#  с оком силой рено другие сводом
#  один мчит зверя дыряв где речка круг страшно нипочем
#  вослед ждет молвил он ты иль среди
#  я и так из я понял мою
#  так был <UNK> и вращает
#  и я ты сетуй обжигаю терзаем
#  вдруг сказал от слипшиеся
#  когда вовек грезя сходят казним глаза тогда чье дорогу устрашен
#  и бока небесам улитки единым вожатый о подземными твой раньше <UNK> <UNK> <UNK>
#  христос <UNK> <UNK> <UNK> <UNK>
#  который как корм отвечала воздухе открытом
#  а той на был великий
#  любовь и руки людям не
#  и какойто искони которой пупа
#  кто вождь раньше достойные своим есть
#  но и если как велел других
#  нельзя и здравый
#  не теней сын пламя <UNK>
#  пора душах <UNK> <UNK> <UNK>
#  <UNK> <UNK> <UNK> <UNK> <UNK>
#  <UNK> правдой <UNK> неозаренной бытия
#  заговори всем вон ближним стал небом двое сказал клонит
#  и жив меня тех с ним добро стал идущий и славой
#  и дочь на <UNK> мне
#  и он читатель я понесшей во тесниной
#  то мне почему с <UNK> укрыться
#  когда круг народ мог
#  мне о опять небу для как тот но всем
#  пустыне взгляни и остановясь шли дан пора
#  которая бросил бледнели его покровы
#  он были и духи путем
#  и если бы меня когда отец
#  и <UNK> его <UNK> <UNK>
#  а всей арно до две
#  без огонь руку нельзя
#  уже того <UNK> <UNK> <UNK>
#  мы новый <UNK> кого нипочем
#  перелетели <UNK> да в <UNK> дрянь
#  что речь лес равны этой богом их людей
#  и другим припомянув и темной рядом <UNK> избранный
#  шестой же ни ногам вполне
#  не очутился без грех рвы
#  могли он с тобой верного ни с порога
#  в лицо мощен не <UNK>
#  с четверо рядом ковача дается
#  сказал ко с сотни назад
#  проклятый туда бездной но из но те отдыха
#  который том вожатый <UNK> владел
#  <UNK> лицо <UNK> и не <UNK>
#  <UNK> <UNK> <UNK> слава
#  кто вблизи несчастным болью внутри
#  они был <UNK> путь
#  вдруг скорбно
#  и я стряхивая вожатый устало
#  который обитель от много
#  и мы потом убит
#  и если под мой жгут <UNK>
#  и <UNK> когда <UNK> в <UNK>
#  их то меня нам в объята с них стезею
#  они исполин из идет поневоле
#  о они и так корнето точило наружу вод несущей взвод оно ризе держали вверх хуже луна злой следом испаренья предотвратить кругом подсобясь казнил являешь меняют каменистый мореходам совет грозен зверь скрепляет справляют неустанно убегает разность костяк невозможно благодать прозвучал спят родит тебе собака славил ними здесь ястребперемыт сигнул рвущимся барбос утешенье
#  не и я трижды стал гомита
#  я молвил что смотри ни раз
#  упасть сгинул воспринял мир наших всплывет
#  я тальякоццо вперед я <UNK> за и лишь вид
#  в одном голосе молвил есть
#  и шли создал питал левой
#  иной с раньше до была
#  и знай и в него непокорно
#  крут к а змеился отошли
#  чтобы мне взятки ему навстречу
#  <UNK> сделал глубине
#  к щель французов подает уцепился
#  и опоясав в попустому украл
#  между словом горе естества кричали пламень полянам
#  ведь здесь выйдя пищу унести бесплодный
#  знай свет бы не рассказ
#  взгляд солнце <UNK> посмотреть завидно
#  что краткий поднесь благодарю рано лживо возьмет дня еще глубок втихомолку
#  но точке больному и громадой <UNK> водопаду
#  но угодно отстраняли беседы я так костра
#  и вонзая ответил со него воспалила
#  чтоб здесь в чьем с нас
#  я вижу на этот мольбу
#  уже то сонм был вдали он смесь злосчастный
#  но жив плакать двумя к нам
#  не лучи <UNK> не проснувшись
#  когда то ей он страшно
#  я солнца волей и вот
#  о образ и они
#  но на миг и исчез таким
#  мы бы нам величавый
#  <UNK> порог цветов хребте
#  являл зацепить выступа как внушенный
#  все в правде тот лоб

# %% [markdown]
# ### Text generated by the language model with lowest test perplexity

# %%
print(df_comp_model[df_comp_model['model_type'] == 'ngram_lm'].sort_values('test_perplexity')['generated text'].values[0])
# Out:
# пиза ускорим звуком однажды стычкам разговору блудной темной приводит улыбкой держись висячий прочно влипли странно верхним заключено даль глазами сдирающие хрюкала разумом планета мглистыми взирая
